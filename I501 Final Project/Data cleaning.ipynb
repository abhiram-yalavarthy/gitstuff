# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\abhir\\OneDrive\\Desktop\\ADS\\gitstuff\\I501 Final Project\\Vegetables_Pulses2023.csv")
df
# Out:
# C:\Users\abhir\AppData\Local\Temp\ipykernel_24228\2244254823.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#       Decade  Year                     Item           Commodity  \
# 0      1970s  1970    Domestic availability          Artichokes
# 1      1970s  1970             Total supply          Artichokes
# 2      1970s  1970  Per capita availability          Artichokes
# 3      1970s  1970          Current dollars          Artichokes
# 4      1970s  1970               Production          Artichokes
# ...      ...   ...                      ...                 ...
# 39148  2020s  2021               Production  Vegetables primary
# 39149  2020s  2021               Production  Vegetables primary
# 39150  2020s  2021               Production  Vegetables primary
# 39151  2020s  2021               Production  Vegetables primary
# 39152  2020s  2021               Production  Vegetables primary
#
#                            EndUse  PublishValue            Unit  \
# 0      Dual, fresh and processing       95.6000  Million pounds
# 1      Dual, fresh and processing       95.6000  Million pounds
# 2      Dual, fresh and processing        0.4662          Pounds
# 3      Dual, fresh and processing       10.3000           $/cwt
# 4      Dual, fresh and processing       67.1000  Million pounds
# ...                           ...           ...             ...
# 39148                    All uses    25455.0000     Million cwt
# 39149                    All uses    13228.0000     Million cwt
# 39150                    All uses     7602.0000     Million cwt
# 39151                    All uses      587.0000     Million cwt
# 39152                    All uses     3042.0000     Million cwt
#
#                    Category GeographicalLevel             Location
# 0              Availability           Country        United States
# 1                    Supply           Country        United States
# 2              Availability           Country        United States
# 3      Season average price           Country        United States
# 4                    Supply           Country        United States
# ...                     ...               ...                  ...
# 39148                Supply           Country                World
# 39149                Supply           Country      China, mainland
# 39150                Supply           Country  All other countries
# 39151                Supply           Country               Turkey
# 39152                Supply           Country                India
#
# [39153 rows x 10 columns]

# %%
df.dropna(inplace=True)
print(df.head(10))
# Out:
#   Decade  Year                     Item   Commodity  \
# 0  1970s  1970    Domestic availability  Artichokes
# 1  1970s  1970             Total supply  Artichokes
# 2  1970s  1970  Per capita availability  Artichokes
# 3  1970s  1970          Current dollars  Artichokes
# 4  1970s  1970               Production  Artichokes
# 5  1970s  1970                  Imports  Artichokes
# 6  1970s  1970    Constant 2012 dollars  Artichokes
# 7  1970s  1971    Domestic availability  Artichokes
# 8  1970s  1971             Total supply  Artichokes
# 9  1970s  1971  Per capita availability  Artichokes
#
#                        EndUse  PublishValue            Unit  \
# 0  Dual, fresh and processing       95.6000  Million pounds
# 1  Dual, fresh and processing       95.6000  Million pounds
# 2  Dual, fresh and processing        0.4662          Pounds
# 3  Dual, fresh and processing       10.3000           $/cwt
# 4  Dual, fresh and processing       67.1000  Million pounds
# 5  Dual, fresh and processing       28.5000  Million pounds
# 6  Dual, fresh and processing       47.5158           $/cwt
# 7  Dual, fresh and processing      105.3000  Million pounds
# 8  Dual, fresh and processing      105.3000  Million pounds
# 9  Dual, fresh and processing        0.5071          Pounds
#
#                Category GeographicalLevel       Location
# 0          Availability           Country  United States
# 1                Supply           Country  United States
# 2          Availability           Country  United States
# 3  Season average price           Country  United States
# 4                Supply           Country  United States
# 5                Supply           Country  United States
# 6  Season average price           Country  United States
# 7          Availability           Country  United States
# 8                Supply           Country  United States
# 9          Availability           Country  United States

# %%
df.drop_duplicates(inplace=True)
# Out:
#       Decade  Year                     Item           Commodity  \
# 0      1970s  1970    Domestic availability          Artichokes
# 1      1970s  1970             Total supply          Artichokes
# 2      1970s  1970  Per capita availability          Artichokes
# 3      1970s  1970          Current dollars          Artichokes
# 4      1970s  1970               Production          Artichokes
# ...      ...   ...                      ...                 ...
# 39148  2020s  2021               Production  Vegetables primary
# 39149  2020s  2021               Production  Vegetables primary
# 39150  2020s  2021               Production  Vegetables primary
# 39151  2020s  2021               Production  Vegetables primary
# 39152  2020s  2021               Production  Vegetables primary
#
#                            EndUse  PublishValue            Unit  \
# 0      Dual, fresh and processing       95.6000  Million pounds
# 1      Dual, fresh and processing       95.6000  Million pounds
# 2      Dual, fresh and processing        0.4662          Pounds
# 3      Dual, fresh and processing       10.3000           $/cwt
# 4      Dual, fresh and processing       67.1000  Million pounds
# ...                           ...           ...             ...
# 39148                    All uses    25455.0000     Million cwt
# 39149                    All uses    13228.0000     Million cwt
# 39150                    All uses     7602.0000     Million cwt
# 39151                    All uses      587.0000     Million cwt
# 39152                    All uses     3042.0000     Million cwt
#
#                    Category GeographicalLevel             Location
# 0              Availability           Country        United States
# 1                    Supply           Country        United States
# 2              Availability           Country        United States
# 3      Season average price           Country        United States
# 4                    Supply           Country        United States
# ...                     ...               ...                  ...
# 39148                Supply           Country                World
# 39149                Supply           Country      China, mainland
# 39150                Supply           Country  All other countries
# 39151                Supply           Country               Turkey
# 39152                Supply           Country                India
#
# [39153 rows x 10 columns]

# %%
df.shape
df.head(10)
# Out:
#   Decade  Year                     Item   Commodity  \
# 0  1970s  1970    Domestic availability  Artichokes
# 1  1970s  1970             Total supply  Artichokes
# 2  1970s  1970  Per capita availability  Artichokes
# 3  1970s  1970          Current dollars  Artichokes
# 4  1970s  1970               Production  Artichokes
# 5  1970s  1970                  Imports  Artichokes
# 6  1970s  1970    Constant 2012 dollars  Artichokes
# 7  1970s  1971    Domestic availability  Artichokes
# 8  1970s  1971             Total supply  Artichokes
# 9  1970s  1971  Per capita availability  Artichokes
#
#                        EndUse  PublishValue            Unit  \
# 0  Dual, fresh and processing       95.6000  Million pounds
# 1  Dual, fresh and processing       95.6000  Million pounds
# 2  Dual, fresh and processing        0.4662          Pounds
# 3  Dual, fresh and processing       10.3000           $/cwt
# 4  Dual, fresh and processing       67.1000  Million pounds
# 5  Dual, fresh and processing       28.5000  Million pounds
# 6  Dual, fresh and processing       47.5158           $/cwt
# 7  Dual, fresh and processing      105.3000  Million pounds
# 8  Dual, fresh and processing      105.3000  Million pounds
# 9  Dual, fresh and processing        0.5071          Pounds
#
#                Category GeographicalLevel       Location
# 0          Availability           Country  United States
# 1                Supply           Country  United States
# 2          Availability           Country  United States
# 3  Season average price           Country  United States
# 4                Supply           Country  United States
# 5                Supply           Country  United States
# 6  Season average price           Country  United States
# 7          Availability           Country  United States
# 8                Supply           Country  United States
# 9          Availability           Country  United States
