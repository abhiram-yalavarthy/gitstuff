# %% [markdown]
# # Intro to Natural Language Processing (NLP)
#
# The Natural Language Processing (NLP) field is incredibly vast, and it has applications in virtually every aspect of data science. In this notebook, we will walk through a **very brief** survey of NLP, and provide some instruction on a couple handy tools along the way.
#
# NLP tools span a wide range of implementations, and it is not uncommon for NLP packages to have conflicts with other Python libraries. So, to keep everything compatible in one place, it is recommended that you create a new pip environment for NLP projects. To set up an NLP pip environment for this lab, follow the steps in the "Pip Environment" section of the [Python Environment Setup page in Canvas](https://iu.instructure.com/courses/2181786/pages/week-1-%7C-python-environment-setup?module_item_id=30340853), and **use the *environment.yml* file provided in this folder.** This should install the packages you'll need for this lab.
#
# Next, **[download a spaCy NLP model](https://spacy.io/models)** based on your preferences (in the NLP environment) so you can use the spaCy library installed in the environment.
#
# *Optionally, if you prefer to use a different environment, install the following packages separately using pip: [Scikit-Learn](https://scikit-learn.org/stable/install.html#installing-the-latest-release), [spaCy](https://spacy.io/usage), [ScatterText](https://github.com/JasonKessler/scattertext#installation), [CorEx](https://ryanjgallagher.github.io/code/corex/example), and [vaderSentiment](https://github.com/cjhutto/vaderSentiment#installation).*

# %% [markdown]
# ## Preprocessing
#
# To illustrate preprocessing text data, we'll use the [spaCy](https://spacy.io/) package.
#
# *spaCy is capable of **much** more than what we will use it for in this lab. More advanced implementations of spaCy may require knowledge outside the scope of this course.*

# %%
import pandas as pd
import spacy
from spacy import displacy
print(spacy.__version__)
# Out:
# 3.7.1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ### Tokenizing
#
# The very first part of dealing with text data is to collect each **term** or unitary element of text (e.g., words, punctuation, etc.) in the form of "tokens".

# %%
# depends on your choice of spaCy model
nlp = spacy.load('en_core_web_sm')

# %%
intro = '''The Natural Language Processing (NLP) field is incredibly vast,
and it has applications in virtually every aspect of data science.
In this notebook, we will walk through a **very brief** survey of NLP,
and provide some instruction on a couple handy tools along the way.
'''

doc = nlp(intro)

# %%
print([t.text for t in doc])
# Out:
# ['The', 'Natural', 'Language', 'Processing', '(', 'NLP', ')', 'field', 'is', 'incredibly', 'vast', ',', '\n', 'and', 'it', 'has', 'applications', 'in', 'virtually', 'every', 'aspect', 'of', 'data', 'science', '.', '\n', 'In', 'this', 'notebook', ',', 'we', 'will', 'walk', 'through', 'a', '*', '*', 'very', 'brief', '*', '*', 'survey', 'of', 'NLP', ',', '\n', 'and', 'provide', 'some', 'instruction', 'on', 'a', 'couple', 'handy', 'tools', 'along', 'the', 'way', '.', '\n']

# %%
for i, sentence in enumerate(doc.sents):
    print(f"sentence {i+1}\n\n", sentence)
# Out:
# sentence 1
#
#  The Natural Language Processing (NLP) field is incredibly vast,
# and it has applications in virtually every aspect of data science.
#
# sentence 2
#
#  In this notebook, we will walk through a **very brief** survey of NLP,
# and provide some instruction on a couple handy tools along the way.

# %%
df_intro = []

for token in doc:
    df_intro.append([
        token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
        token.shape_, token.is_alpha, token.is_stop
    ])

# %%
df_intro = pd.DataFrame(columns=["text", "lemma_", "pos_", "tag_", "dep_", "shape_", "is_alpha", "is_stop"],
                        data=df_intro)

# %%
df_intro.sample(5)
# Out:
#      text lemma_   pos_ tag_    dep_ shape_  is_alpha  is_stop
# 19  every  every   PRON   DT  nummod   xxxx      True     True
# 39      *      *   NOUN   NN    pobj      *     False    False
# 10   vast   vast    ADJ   JJ   acomp   xxxx      True    False
# 43    NLP    NLP  PROPN  NNP    pobj    XXX      True    False
# 34      a      a    DET   DT     det      x      True     True

# %% [markdown]
# What is a **stop word**?

# %%
df_intro[df_intro['is_stop']].sample(10)
# Out:
#        text   lemma_   pos_ tag_      dep_ shape_  is_alpha  is_stop
# 14       it       it   PRON  PRP     nsubj     xx      True     True
# 15      has     have   VERB  VBZ      conj    xxx      True     True
# 51        a        a    DET   DT  quantmod      x      True     True
# 19    every    every   PRON   DT    nummod   xxxx      True     True
# 33  through  through    ADP   IN      prep   xxxx      True     True
# 0       The      the    DET   DT       det    Xxx      True     True
# 31     will     will    AUX   MD       aux   xxxx      True     True
# 13      and      and  CCONJ   CC        cc    xxx      True     True
# 46      and      and  CCONJ   CC        cc    xxx      True     True
# 17       in       in    ADP   IN      prep     xx      True     True

# %% [markdown]
# spaCy defines **lemmas** to be *"the base forms of words. For example, the lemma of `was` is `be`, and the lemma of `rats` is `rat`."*

# %%
t = nlp('running')[0]
t.lemma_
# Out:
# 'run'

# %% [markdown]
# **Sentence Dependencies**

# %% [markdown]
# We can visualize some of these attributes (like the sentence dependencies) using [displacy](https://spacy.io/usage/visualizers).

# %%
doc = nlp('We can visualize these using displacy.')

# %%
displacy.render(doc, style='dep', options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="dd7ee3509d234691823e43396e816d9e-0" class="displacy" width="770" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">visualize</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">displacy.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd7ee3509d234691823e43396e816d9e-0-0" stroke-width="2px" d="M70,182.0 C70,62.0 285.0,62.0 285.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd7ee3509d234691823e43396e816d9e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd7ee3509d234691823e43396e816d9e-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd7ee3509d234691823e43396e816d9e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd7ee3509d234691823e43396e816d9e-0-2" stroke-width="2px" d="M430,182.0 C430,62.0 645.0,62.0 645.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd7ee3509d234691823e43396e816d9e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd7ee3509d234691823e43396e816d9e-0-3" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd7ee3509d234691823e43396e816d9e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd7ee3509d234691823e43396e816d9e-0-4" stroke-width="2px" d="M310,182.0 C310,2.0 650.0,2.0 650.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd7ee3509d234691823e43396e816d9e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,184.0 L658.0,172.0 642.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Note: this isn't always going to be *exactly* accurate, but it's very good and still useful.

# %% [markdown]
# ### Named Entity Recognition
#
# Some words are **Named Entities**: locations like "Alaska", dates like "January 1st", companies like "Google", etc. spaCy can tag these using [Named Entity Recognition](https://spacy.io/usage/linguistic-features#named-entities).

# %%
doc = nlp('... locations like "Alaska", dates like "January 1st", companies like "Google", etc.')

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">... locations like &quot;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alaska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot;, dates like &quot;
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# &quot;, companies like &quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# &quot;, etc.</div></span>

# %% [markdown]
# ### Multiple Documents
#
# *NLP Terms: A **document** is a collection of **tokens**, and a **corpus** is a collection of documents.*
#
# When spaCy processes text, it runs it through a [pipeline](https://spacy.io/usage/processing-pipelines) of different models to store token attributes for each token. This is how we get the functionality above. Though, when we are tokenizing multiple documents, we might not need all of these [built-in components](https://spacy.io/usage/processing-pipelines#built-in). For example, we might just need enough to filter our text based on the analysis done.
#
# For example, suppose we've determined that we want to the remove the following tokens from a dataset of [coffee reviews](https://www.kaggle.com/datasets/schmoyote/coffee-reviews-dataset/) (descriptions):
#
# - stop words (except the lemma "not", to maintain the idea of object negation)
# - punctuation
# - numbers
#
# In this case, we don't need NER, Dependency Labels, or Document Labels. Removing these processes from the spaCy pipeline will save us some time.

# %%
df_coffee = pd.read_csv('./data/coffee_analysis.csv')

# %%
df_coffee.drop_duplicates(subset='desc_1', inplace=True)

# %%
df_coffee.shape
# Out:
# (2092, 12)

# %%
print(df_coffee['desc_1'].sample().iloc[0])
# Out:
# Floral-toned, richly sweet-savory. Black cherry, dark chocolate, marjoram, sandalwood, agave syrup in aroma and cup. Sweetly tart structure with brisk acidity; syrupy-smooth mouthfeel. The finish leads with notes of black cherry, rounding to cocoa tones in the long.

# %%
# nlp.pipe returns a generator
docs = nlp.pipe(df_coffee['desc_1'], disable=['ner', 'parser', 'textcat'])

# save the spaCy objects into the DataFrame
df_coffee['spacy_doc'] = list(docs)

# %%
def tokenizer(doc, join_tokens=False):
    '''
    Tokenize a single spaCy `doc`.

    join_tokens : bool
        Whether we want to return a list of strings or
        a list of lists. If True, join with space (" ").
    '''

    # collect lemmas that meet the following criteria:
    tokens = [w.lemma_.lower() for w in doc if
              (not w.is_stop
               and not w.is_punct
               and not w.like_num) \
              or (w.lemma_ == 'not')]

    if join_tokens:
        return ' '.join(tokens)
    else:
        return tokens

# %%
df_coffee['docs_clean'] = df_coffee['spacy_doc'].apply(tokenizer)

# %%
df_coffee[['desc_1', 'spacy_doc', 'docs_clean']].head()
# Out:
#                                               desc_1  \
# 0  Evaluated as espresso. Sweet-toned, deeply ric...
# 1  Evaluated as espresso. Sweetly tart, floral-to...
# 2  Crisply sweet, cocoa-toned. Lemon blossom, roa...
# 3  Delicate, sweetly spice-toned. Pink peppercorn...
# 4  Deeply sweet, subtly pungent. Honey, pear, tan...
#
#                                            spacy_doc  \
# 0  (Evaluated, as, espresso, ., Sweet, -, toned, ...
# 1  (Evaluated, as, espresso, ., Sweetly, tart, ,,...
# 2  (Crisply, sweet, ,, cocoa, -, toned, ., Lemon,...
# 3  (Delicate, ,, sweetly, spice, -, toned, ., Pin...
# 4  (Deeply, sweet, ,, subtly, pungent, ., Honey, ...
#
#                                           docs_clean
# 0  [evaluate, espresso, sweet, tone, deeply, rich...
# 1  [evaluate, espresso, sweetly, tart, floral, to...
# 2  [crisply, sweet, cocoa, tone, lemon, blossom, ...
# 3  [delicate, sweetly, spice, tone, pink, pepperc...
# 4  [deeply, sweet, subtly, pungent, honey, pear, ...

# %%
print(df_coffee['desc_1'].iloc[5])
# Out:
# Delicate, richly and sweetly tart. Dried hibiscus, fine musk, almond, sandalwood, raspberry in aroma and cup. Fruit-toned, deeply sweet structure with gently-expressed acidity; buoyant, satiny-smooth mouthfeel. The crisp, flavor-saturated finish is characterized by sweet-tart fruit and floral tones (raspberry, hibiscus).

# %%
print(df_coffee['docs_clean'].iloc[5])
# Out:
# ['delicate', 'richly', 'sweetly', 'tart', 'dry', 'hibiscus', 'fine', 'musk', 'almond', 'sandalwood', 'raspberry', 'aroma', 'cup', 'fruit', 'tone', 'deeply', 'sweet', 'structure', 'gently', 'express', 'acidity', 'buoyant', 'satiny', 'smooth', 'mouthfeel', 'crisp', 'flavor', 'saturate', 'finish', 'characterize', 'sweet', 'tart', 'fruit', 'floral', 'tone', 'raspberry', 'hibiscus']

# %% [markdown]
# ## Vectorization
#
# Once we have our tokens selected and "cleaned", we need to convert the textual data into numerical data. **In other words, we need to convert each token (or document) into a *vector* representation.** There are many ways to represent textual information in the form of numerical data, but in this class we will cover Count Vectorization and Term-Frequency Inverse Document Frequency Vectorization; we'll call these **vectorizers**.

# %% [markdown]
# ### Brief Intro to Scikit-Learn
#
# **[Scikit-Learn](https://scikit-learn.org/stable/index.html) is the industry standard data science toolkit**, and it's modules are used in almost every aspect of data science. Here, we are going to use its [feature extraction module](https://scikit-learn.org/stable/modules/feature_extraction.html), which is built for extracting numerical features from data such as text or images. We will be using it for vectorization of text data, and in these cases, the scikit-learn process is:
#
# 1. Preprocess some data (e.g., from text to tokens)
# 2. Define a model (e.g., a vectorizer)
# 3. "Fit" that model to the data using `.fit`
# 4. Transform the data based on the model's parameters using `.transform`
#     - We can also combine these last two steps with `.fit_transform`

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ### CountVectorizer
#
# CountVectorizer converts each document into a "Bag of Words". In other words, the document is encoded based on the words it contains, **regardless of the order**. And, each term can be represented based on the documents it is contained in.

# %%
corpus_raw = ['This coffee is really really tasty.',
              'Tea smells and tastes better than coffee.',
              "Best smelling coffee I have ever smelled!"]

# %%
cv = CountVectorizer(ngram_range=(1, 1),  # capture "pairs", or "n-tuples" of adjacent words
                     max_df=1.0,          # exclude terms in ≥ `max_df` (or %) of docs
                     min_df=1,            # exclude terms in ≤ `min_df` (or %) of docs
                     max_features=None,   # maximum number of terms/ngrams to include
                     binary=False)        # only log 1s and 0s for term presence

X = cv.fit_transform(corpus_raw)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(8, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %% [markdown]
# This is called a **document-term matrix**.
#
# - We could use `max_df` to remove the term "coffee" since it occurs in every document. This is one example of extracting *informative* features from text; i.e., the term "coffee" doesn't provide new information for each document.
# - Also, we can already see that some of these words give us more information than others. For example, "smelling" and "smells" mean roughly the same thing, and "had"/"have" aren't really necessary for understanding reviews.
#
# This is why we use the filtering in spaCy.

# %%
docs = nlp.pipe(corpus_raw)
corpus_clean = [tokenizer(d, True) for d in docs]
corpus_clean
# Out:
# ['coffee tasty', 'tea smell taste well coffee', 'good smell coffee smell']

# %%
cv = CountVectorizer(ngram_range=(1, 1),
                     max_df=0.9,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(6, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %%
cv = CountVectorizer(ngram_range=(2, 2),  # use (1, 2) for unigrams *and* bigrams
                     max_df=0.9,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(10, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %% [markdown]
# Now these vectors are a bit more meaningful. Notice, in a way, bigrams are a contrived way to capture context in textual data.

# %% [markdown]
# ### TFIDF Vectorizer
#
# Downsides of Count Vectorizer:
#
# - Counts can be too simplistic
# - High counts can dominate, especially for high frequency words or long documents
# - Each word is treated equally, when some terms might be more "important" than others
#
# We define TFIDF as:
#
# $$
# \text{TF-IDF} = \text{term frequency} * \text{inverse document frequency}
# $$
#
# where:
#
# $$
# \begin{align*}
# \text{term frequency} &= \frac{\text{term count in document}}{\text{total terms in document}} \\[8pt]
# \text{inverse document frequency} &= \log\bigg(\frac{\text{total number of documents} + 1}{\text{number of documents with term} + 1}\bigg)
# \end{align*}
# $$

# %% [markdown]
# This measure is calculated for every term-document combination:
#
# - The **term frequency** measures the "density" of a word in a document
# - The **inverse document frequency** (without the $\log$) measures the size of the corpus *in terms of* the number of documents containing the term. E.g., if IDF=5 then the corpus is 5 times the size of the "sub-corpus" of documents containing the term. The $\log$ dampens the effect of the inverse document frequency as the denominator gets very small or the numerator gets very large.
#
# So, we can think of TF as the "main" measure, and IDF as the "scaling" factor:
#
# - Very common words across all documents will get a lower score.
# - Rare words considering all documents get a higher score.

# %%
cv = TfidfVectorizer(max_df=1.0,
                     min_df=1,
                     max_features=None)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())

# %%
sns.heatmap(df, square=True, cmap='Blues', annot=True, cbar=False);

# %% [markdown]
# ## Topic Modeling
#
# ### Matrix Decomposition
#
# The document term matrix $X$ is a matrix just like any other in Linear Algebra. Just so, it defines a row space (the documents represented as linear combinations of terms), and column space (terms represented as a linear combination of documents). With this, there are a few matrix decomposition methods we can use to extract further information about these documents and terms.

# %%
from sklearn.decomposition import TruncatedSVD, NMF, PCA

# %% [markdown]
# ### Singular Value Decomposition
#
# Singular Value Decomposition is a guaranteed decomposition for any rectangular matrix. It creates the following equality:
#
# $$
# X = U\Sigma V^\top
# $$
#
# **Breifly**:
# - Each row of $U$ represents the corresponding document in terms of "topics directions" along the columns.
# - The rows of $V$ (columns of $V^\top$) represent similarly represented version of the terms.
# - The $\Sigma$ matrix contains the "variance explained" by each of these topics, sorted in descending order.
#
# As far as naming goes:
#
# - The analysis of these resulting matrices is called **Principal Components Analysis (PCA)**.
# - When used with text data, this analysis is called **Latent Semantic Analysis (LSA)**.

# %%
# we need a list/array of strings to vectorize
corpus = df_coffee['spacy_doc'].apply(tokenizer, args={'join_tokens':True})

# %%
corpus.shape
# Out:
# (2092,)

# %%
cv = TfidfVectorizer(max_df=0.9,
                     min_df=0.1,
                     max_features=None)

X = cv.fit_transform(corpus)
# df = pd.DataFrame(X, index=corpus, columns=cv.get_feature_names_out())

# %%
X.shape
# Out:
# (2092, 65)

# %% [markdown]
# Note, we use `TruncatedSVD` here because it's a more efficient implementation of SVD. PCA centers the data before running the algorithm, which is more "appropriate" but takes more time. This does cause a few inconsistencies in the "sorted" $\Sigma$.

# %%
lsa = TruncatedSVD(n_components=5)  # results only change for larger (unseen) values

doc_topic = lsa.fit_transform(X)
lsa.explained_variance_ratio_
# Out:
# array([0.00488089, 0.08197356, 0.04777372, 0.0467806 , 0.03499091])

# %%
doc_topic = pd.DataFrame(doc_topic.round(3),
                         index=df_coffee['desc_1'])
# doc_topic.head()

# %%
topic = 1
n_docs = 5

print(f"Top Documents for topic {topic}:\n")

for doc in doc_topic[topic].abs().sort_values(ascending=False).iloc[:n_docs].index:
    print(doc, '\n')
# Out:
# Top Documents for topic 1:
#
# Sweetly floral and delicately cocoa-toned. Honeysuckle, cocoa nib, Concord grape, agave, lemon-thyme in aroma and cup. High-toned structure with juicy, confident acidity; buoyant, lively, viscous mouthfeel. Honeysuckle and cocoa nib characterize the sweet finish.
#
# Evaluated as espresso. Roast-rounded, chocolaty. Dark chocolate, gardenia, gently scorched cedar, molasses, prune in aroma and small cup. Viscous, creamy mouthfeel; chocolaty, slightly smoky finish. In three parts milk, floral and chocolate notes preside.
#
# Evaluated as espresso. Fruit-forward, chocolaty. Dark chocolate, black cherry, lily, molasses, cedar in aroma and small cup. Very syrupy mouthfeel; crisp, chocolaty finish. In three parts milk, dark chocolate notes take center stage, supported by notes of black cherry and lily.
#
# Evaluated as espresso. Bittersweet, richly pungent, chocolaty and floral. Dark chocolate, plum, cedar, magnolia in aroma and small cup. Plump, satiny mouthfeel; bittersweet and chocolaty in the finish. Chocolate and flowers dominate in three parts milk.
#
# Delicately sweet-tart, floral-toned. Narcissus, apricot, cocoa nib, lemon verbena, frankincense in aroma and cup. Sweet-tart structure with delicately juicy acidity; very full, syrupy mouthfeel. Cocoa nib and narcissus focus the long, lingering finish.

# %%
topic_term = pd.DataFrame(lsa.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.192   0.124  0.090     0.103   0.117  0.072   0.068  0.167   0.082
# 1    0.072  -0.025 -0.142     0.065   0.120 -0.019  -0.019 -0.107  -0.003
# 2    0.038   0.066  0.300    -0.046  -0.126  0.197   0.057  0.150  -0.008
# 3   -0.121   0.011 -0.110    -0.007   0.011 -0.085   0.033  0.066  -0.012
# 4   -0.082  -0.171 -0.118     0.018  -0.164 -0.027  -0.081 -0.115  -0.054
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.256  ...  0.280    0.146  0.079   0.144  0.195  0.249      0.077
# 1     -0.461  ...  0.034    0.029  0.041   0.038  0.113  0.032     -0.016
# 2     -0.071  ...  0.098   -0.053  0.056  -0.149 -0.103  0.107      0.057
# 3     -0.031  ... -0.173   -0.038 -0.046  -0.041  0.032  0.097      0.005
# 4     -0.063  ...  0.086   -0.157 -0.057   0.045 -0.382 -0.070      0.035
#
#    velvety  vibrant   zest
# 0    0.070    0.066  0.148
# 1   -0.046    0.070  0.040
# 2    0.127   -0.090  0.019
# 3   -0.014   -0.018  0.011
# 4    0.016   -0.049 -0.064
#
# [5 rows x 65 columns]

# %%
# the third "topic"
topic = 2
n_terms = 10

topic_term.T[topic].abs().sort_values(ascending=False).iloc[:n_terms]
# Out:
# bake          0.300
# sandalwood    0.268
# dark          0.258
# nut           0.237
# flavor        0.218
# savory        0.207
# juicy         0.207
# cut           0.198
# brisk         0.197
# hazelnut      0.189
# Name: 2, dtype: float64

# %% [markdown]
# ### Non-Negative Matrix Factorization
#
# [NMF](https://en.wikipedia.org/wiki/Non-negative_matrix_factorization) is very similar to SVD. Here, we have the following decomposition.
#
# $$
# X = WH
# $$
#
# In this case though, all values in $W$ and $H$ are positive, and we can *approximate* this decomposition because all values in $X$ are positive.

# %%
nmf = NMF(4)  # here, the number will change the results
doc_topic = nmf.fit_transform(X)

# %%
doc_topic = pd.DataFrame(doc_topic.round(3),
                         index=df_coffee['desc_1'])
# doc_topic.head()

# %%
topic = 1
n_docs = 5

print(f"Top Documents for topic {topic}:\n")

for doc in doc_topic[topic].abs().sort_values(ascending=False).iloc[:n_docs].index:
    print(doc, '\n')
# Out:
# Top Documents for topic 1:
#
# Evaluated as espresso. Fruit-forward, chocolaty. Dark chocolate, black cherry, lily, molasses, cedar in aroma and small cup. Very syrupy mouthfeel; crisp, chocolaty finish. In three parts milk, dark chocolate notes take center stage, supported by notes of black cherry and lily.
#
# Evaluated as espresso. Bittersweet, richly pungent, chocolaty and floral. Dark chocolate, plum, cedar, magnolia in aroma and small cup. Plump, satiny mouthfeel; bittersweet and chocolaty in the finish. Chocolate and flowers dominate in three parts milk.
#
# Evaluated as espresso. Deeply chocolaty, balanced, roast-rounded. Dark chocolate, nectarine, molasses, gently scorched cedar, rhododendron in aroma and small cup. Full, satiny mouthfeel; crisp, chocolaty finish. In three parts milk the dark chocolate notes are amplified, as are the florals
#
# Evaluated as espresso. Roast-rounded, chocolaty. Dark chocolate, gardenia, gently scorched cedar, molasses, prune in aroma and small cup. Viscous, creamy mouthfeel; chocolaty, slightly smoky finish. In three parts milk, floral and chocolate notes preside.
#
# Evaluated as espresso. Richly chocolaty, fruit-toned. Dark chocolate, raspberry jam, cedar, caramel, lemon verbena in aroma and small cup. Crisp, syrupy-smooth mouthfeel; chocolaty, sweetly herbaceous finish. In three parts milk, raspberry notes recede and caramel and chocolate come forward.

# %%
topic_term = pd.DataFrame(nmf.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.934   0.391  0.000     0.612   0.863  0.000   0.083  0.022   0.351
# 1    0.000   0.173  0.000     0.047   0.000  0.000   0.133  0.603   0.114
# 2    0.547   0.485  0.961     0.104   0.000  0.611   0.301  0.660   0.210
# 3    0.492   0.163  0.000     0.363   0.487  0.017   0.112  0.284   0.167
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.805  ...  1.422    0.898  0.234   1.221  0.997  0.602      0.091
# 1      1.579  ...  0.029    0.135  0.000   0.173  0.178  0.398      0.179
# 2      0.709  ...  0.897    0.238  0.294   0.032  0.199  0.702      0.276
# 3      0.000  ...  0.503    0.333  0.230   0.308  0.705  0.737      0.192
#
#    velvety  vibrant   zest
# 0    0.000    0.557  0.650
# 1    0.118    0.000  0.136
# 2    0.438    0.000  0.353
# 3    0.048    0.260  0.377
#
# [4 rows x 65 columns]

# %%
topic = 0
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# savory        2.346
# sweet         1.422
# long          1.284
# flavor        1.231
# syrupy        1.221
# sandalwood    1.121
# juicy         1.121
# structure     1.107
# resonant      1.048
# richly        1.023
# Name: 0, dtype: float64

# %%
topic = 1
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# chocolate    1.579
# dark         1.304
# milk         1.131
# espresso     1.126
# evaluate     1.099
# small        1.096
# chocolaty    1.014
# cedar        0.603
# fruit        0.520
# floral       0.493
# Name: 1, dtype: float64

# %% [markdown]
# As you can tell, this often produces more agreeable results than LSA.

# %% [markdown]
# ### Latent Dirichlet Allocation (LDA)
#
# [LDA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html) is a "generative" model that builds topics with the assumption that documents are generated based on a probability distribution of topics, and that topics are just a probability distribution of terms.

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
# these parameters usually require a good bit of tuning ...
lda = LatentDirichletAllocation(n_components=5,
                                max_iter=50)

X_topics = lda.fit_transform(X)

# %%
df_lda = pd.DataFrame(data = X_topics,
                      index = corpus)

# %%
topic = 0
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# richly sweet fruit forward dried apricot cocoa nib star jasmine almond maple syrup aroma cup sweetly tart structure bright juicy acidity crisp syrupy mouthfeel long linger finish center dry apricot cocoa note support cedar like wood
#
# delicate berry tone richly sweet raspberry honey narcissus like flower cedar almond butter aroma cup sweetly tart structure juicy high tone acidity lively mouthfeel resonant flavor saturate finish consolidate note raspberry almond support sweet floral hint
#
# high tone richly fruit forward balanced strawberry guava jasmine cocoa nib sandalwood pink grapefruit zest aroma cup sweet tart structure crisp bright acidity vibrantly plush syrupy mouthfeel resonant finish center guava jasmine note undertone cocoa nib

# %%
topic = 1
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# deeply sweet richly nut tone hazelnut butter magnolia like flower crisp pear cedar agave syrup aroma cup sweet structure gentle round acidity syrupy smooth mouthfeel finish consolidate deep nut rich aromatic wood
#
# fruit tone richly chocolaty dark chocolate dry blueberry freesia like flower honey cedar aroma cup sweet tart structure round gentle acidity syrupy mouthfeel finish consolidate blueberry chocolate note hint cedar
#
# crisply sweet balanced spice tone bake chocolate almond butter date clove magnolia aroma cup sweet structure gentle round acidity plush syrupy mouthfeel chocolaty nut tone finish support magnolia like flower

# %%
df_lda_terms = pd.DataFrame(data = lda.components_,
                            columns = cv.get_feature_names_out())

# %%
topic = 0
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# cocoa        173.729253
# nib          148.041852
# tart          91.054841
# tone          83.626504
# sweet         79.706775
# bright        76.706024
# juicy         74.092692
# acidity       71.742695
# structure     62.287788
# floral        55.370962
# Name: 0, dtype: float64

# %%
topic = 1
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# chocolate    103.755570
# bake          79.127883
# chocolaty     76.855851
# cedar         70.560623
# sweet         69.585832
# tone          57.994594
# gentle        56.010294
# hazelnut      54.467662
# acidity       52.168683
# structure     50.941488
# Name: 1, dtype: float64

# %% [markdown]
# ### Anchored Correlation Explanation (CorEx)
#
# [CorEx](https://github.com/gregversteeg/corex_topic) is a discriminative model, which starts from $X$ (documents/words) to determine $Y$ (topics). CorEx looks for groups of words that are in the same topic, a.k.a. have high Total Correlation (TC), or convey the same information.
#
# - If words are **tightly related** (always appear together in the same topic/document), TC will be high. This is a good topic.
# - If the words are all **independent** (never appear together in the same document or topic), TC = 0. This is a bad topic.
# - CorEx creates a partition across terms. I.e., **terms can only occur in a single topic**.
#
# CorEx roughly follows this algorithm:
# 1. Look for a group of words that are both as broad (in many documents) and overlapping as possible (both together will lead to high TC), and call this a topic.
# 2. Repeat the process for another set of words (not overlapping with your previous group) with as high a TC as possible, and call this the next topic.
#
# As we create more topics, each subsequent topic will have lower TC.

# %%
from corextopic import corextopic as ct

# %%
# CorEx requires count data
cv = CountVectorizer(max_df=0.9,
                     min_df=0.1,
                     max_features=None)

X = cv.fit_transform(corpus)

# %%
topic_model = ct.Corex(n_hidden=5,                        # number of topics
                       words=cv.get_feature_names_out(),  # list of terms in corpus
                       seed=1)

doc_topic = topic_model.fit_transform(X, words=cv.get_feature_names_out(), docs=corpus)

# %%
# Print all topics from the CorEx topic model
topics = topic_model.get_topics()

for n, topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    print(f"{n}: " + ','.join(topic_words))
# Out:
# 0: espresso,evaluate,small,milk,structure,acidity,consolidate,floral,syrup,crisp
# 1: chocolate,dark,nib,cocoa,chocolaty,bake,delicate,lemon,deep,zest
# 2: juicy,cut,gentle,bright,fresh,sandalwood,brisk,tart,high,nut
# 3: short,long,lead,undertone,rich,center,almond
# 4: sweet,sweetly,savory,deeply,fruit,smooth

# %% [markdown]
# Take a look at how you can use [anchor words](https://github.com/gregversteeg/corex_topic/tree/master#using-anchor-words) to guide the topic creation.

# %% [markdown]
# ## ScatterText
#
# Scattertext is great for
# - Visually inspecting text
# - Comparing/Contrasting corpora
# - And more...
#
# Check out Jason Kessler's GitHub project for more information: [here](https://github.com/JasonKessler/scattertext).

# %%
import scattertext as st

# %%
convention_df = st.SampleCorpora.ConventionData2012.get_data()

# %%
convention_df.head()
# Out:
#       party                                               text         speaker
# 0  democrat  Thank you. Thank you. Thank you. Thank you so ...    BARACK OBAMA
# 1  democrat  Thank you so much. Tonight, I am so thrilled a...  MICHELLE OBAMA
# 2  democrat  Thank you. It is a singular honor to be here t...  RICHARD DURBIN
# 3  democrat  Hey, Delaware. \nAnd my favorite Democrat, Jil...    JOSEPH BIDEN
# 4  democrat  Hello. \nThank you, Angie. I'm so proud of how...      JILL BIDEN

# %%
corpus = st.CorpusFromPandas(convention_df,
                             category_col='party',
                             text_col='text',
                             nlp=st.whitespace_nlp_with_sentences
                            ).build()

# %%
html = st.produce_scattertext_explorer(
        corpus,
        category='democrat',
        category_name='Democratic',
        not_category_name='Republican',
        minimum_term_frequency=10,
        pmi_threshold_coefficient=5,
        width_in_pixels=1000,
        metadata=convention_df['speaker'],
        )

# %%
with open('demo.html', 'wb') as f:
    f.write(html.encode('utf-8'))

# %% [markdown]
# ## Sentiment Analysis with VADER
#
# According to the documentation:
#
#     VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media. [...]
#
#     Sentiment ratings from 10 independent human raters (all pre-screened, trained, and quality checked for optimal inter-rater reliability). Over 9,000 token features were rated on a scale from "[–4] Extremely Negative" to "[4] Extremely Positive", with allowance for "[0] Neutral (or Neither, N/A)".

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
sentences = ["VADER is smart, handsome, and funny.",  # positive sentence example
             "VADER is smart, handsome, and funny!",  # punctuation emphasis handled correctly (sentiment intensity adjusted)
             "VADER is very smart, handsome, and funny.", # booster words handled correctly (sentiment intensity adjusted)
             "VADER is VERY SMART, handsome, and FUNNY.",  # emphasis for ALLCAPS handled
             "VADER is VERY SMART, handsome, and FUNNY!!!", # combination of signals - VADER appropriately adjusts intensity
             "VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!", # booster words & punctuation make this close to ceiling for score
             "VADER is not smart, handsome, nor funny.",  # negation sentence example
             "The book was good.",  # positive sentence
             "At least it isn't a horrible book.",  # negated negative sentence with contraction
             "The book was only kind of good.", # qualified positive sentence is handled correctly (intensity adjusted)
             "The plot was good, but the characters are uncompelling and the dialog is not great.", # mixed negation sentence
             "Today SUX!",  # negative slang with capitalization emphasis
             "Today only kinda sux! But I'll get by, lol", # mixed sentiment example with slang and constrastive conjunction "but"
             "Make sure you :) or :D today!",  # emoticons handled
             # "Catch utf-8 emoji such as such as 💘 and 💋 and 😁",  # emojis handled, ignored for seaborn plot below
             "Not bad at all"  # Capitalized negation
             ]

# %%
df_sentiment = []

analyzer = SentimentIntensityAnalyzer()

for sentence in sentences:
    vs = analyzer.polarity_scores(sentence)
    df_sentiment.append(vs)

# %%
df_sentiment = pd.DataFrame(df_sentiment,
                            index = sentences)

# %%
sns.heatmap(df_sentiment, cmap='Blues', annot=True, cbar=False, linewidths=1);

# %% [markdown]
# # EXERCISES

# %% [markdown]
# ## Exercise 1
#
# Using a book from [Project Gutenberg](https://www.gutenberg.org/), get the text data directly from its URL using the `requests` package. Break the book into 50 or more sensible "chunks" like chapters or paragraphs, organizing them into a list.
#
# Load this data into a spaCy pipeline and analyze either Named Entities or Parts of Speech in each chunk.
#
# Provide your analysis: What types of entities or parts of speech are common, and what are uncommon? What insights can you draw from these patterns?
#
# *Note*: Do not download any file, make use of URL in your code.

# %%
import spacy
import requests

# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Fetching the text from the URL
url = "https://www.gutenberg.org/files/11/11-0.txt"
response = requests.get(url)
text = response.text

# Splitting the text into chunks (e.g., paragraphs)
# You may need to adjust the splitting logic based on the structure of the text
# Below is a simple example assuming paragraphs are separated by empty lines
chunks = [chunk.strip() for chunk in text.split('\n\n')]

# Analyze Named Entities or Parts of Speech in each chunk
for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}:")
    
    # Process the chunk with spaCy
    doc = nlp(chunk)
    
    # Analyze Named Entities
    # for ent in doc.ents:
    #     print(ent.text, ent.label_)
    
    # Analyze Parts of Speech
    for token in doc:
        print(token.text, token.pos_)
    
    print('-' * 50)
# Out:
# Chunk 1:
# ï»¿ï PROPN
# » NOUN
# ¿ PROPN
# * PUNCT
# * PUNCT
# * PUNCT
# START NOUN
# OF ADP
# THE DET
# PROJECT PROPN
# GUTENBERG PROPN
# EBOOK VERB
# ALICE PROPN
# 'S PART
# ADVENTURES NOUN
# IN ADP
#
#  SPACE
# WONDERLAND PROPN
# * PUNCT
# * PUNCT
# * PUNCT
#
#  SPACE
# [ X
# Illustration NOUN
# ] PUNCT
#
#
#
#
#
#  SPACE
# Aliceâs PROPN
# Adventures PROPN
# in ADP
# Wonderland PROPN
#
#
#  SPACE
# by ADP
# Lewis PROPN
# Carroll PROPN
#
#
#  SPACE
# THE DET
# MILLENNIUM PROPN
# FULCRUM PROPN
# EDITION PROPN
# 3.0 NUM
#
#
#  SPACE
# Contents PROPN
#
#
#   SPACE
# CHAPTER PROPN
# I. PROPN
#      SPACE
# Down ADP
# the DET
# Rabbit PROPN
# - PUNCT
# Hole PROPN
#
#   SPACE
# CHAPTER PROPN
# II PROPN
# . PUNCT
#     SPACE
# The DET
# Pool PROPN
# of ADP
# Tears PROPN
#
#   SPACE
# CHAPTER PROPN
# III PROPN
# . PUNCT
#    SPACE
# A DET
# Caucus PROPN
# - PUNCT
# Race PROPN
# and CCONJ
# a DET
# Long PROPN
# Tale PROPN
#
#   SPACE
# CHAPTER PROPN
# IV PROPN
# . PUNCT
#     SPACE
# The DET
# Rabbit PROPN
# Sends PROPN
# in ADP
# a DET
# Little PROPN
# Bill PROPN
#
#   SPACE
# CHAPTER PROPN
# V. PROPN
#      SPACE
# Advice PROPN
# from ADP
# a DET
# Caterpillar PROPN
#
#   SPACE
# CHAPTER NOUN
# VI PROPN
# . PUNCT
#     SPACE
# Pig PROPN
# and CCONJ
# Pepper PROPN
#
#   SPACE
# CHAPTER PROPN
# VII PROPN
# . PUNCT
#    SPACE
# A DET
# Mad ADJ
# Tea PROPN
# - PUNCT
# Party PROPN
#
#   SPACE
# CHAPTER PROPN
# VIII PROPN
# . PUNCT
#   SPACE
# The DET
# Queenâs NOUN
# Croquet PROPN
# - PUNCT
# Ground PROPN
#
#   SPACE
# CHAPTER PROPN
# IX PROPN
# . PUNCT
#     SPACE
# The DET
# Mock PROPN
# Turtleâs NOUN
# Story NOUN
#
#   SPACE
# CHAPTER NOUN
# X. PROPN
#      SPACE
# The DET
# Lobster PROPN
# Quadrille PROPN
#
#   SPACE
# CHAPTER PROPN
# XI PROPN
# . PUNCT
#     SPACE
# Who PRON
# Stole VERB
# the DET
# Tarts PROPN
# ? PUNCT
#
#   SPACE
# CHAPTER PROPN
# XII PROPN
# . PUNCT
#    SPACE
# Aliceâs X
# Evidence PROPN
#
#
#
#
#
#  SPACE
# CHAPTER PROPN
# I. PROPN
#
#  SPACE
# Down ADP
# the DET
# Rabbit PROPN
# - PUNCT
# Hole PROPN
#
#
#
#  SPACE
# Alice PROPN
# was AUX
# beginning VERB
# to PART
# get VERB
# very ADV
# tired ADJ
# of ADP
# sitting VERB
# by ADP
# her PRON
# sister NOUN
# on ADP
# the DET
#
#  SPACE
# bank NOUN
# , PUNCT
# and CCONJ
# of ADP
# having VERB
# nothing PRON
# to PART
# do VERB
# : PUNCT
# once ADV
# or CCONJ
# twice ADV
# she PRON
# had AUX
# peeped VERB
# into ADP
#
#  SPACE
# the DET
# book NOUN
# her PRON
# sister NOUN
# was AUX
# reading VERB
# , PUNCT
# but CCONJ
# it PRON
# had VERB
# no DET
# pictures NOUN
# or CCONJ
#
#  SPACE
# conversations NOUN
# in ADP
# it PRON
# , PUNCT
# âand CCONJ
# what PRON
# is AUX
# the DET
# use NOUN
# of ADP
# a DET
# book NOUN
# , PUNCT
# â PROPN
# thought VERB
# Alice PROPN
#
#  SPACE
# âwithout NOUN
# pictures NOUN
# or CCONJ
# conversations?â NOUN
#
#
#  SPACE
# So ADV
# she PRON
# was AUX
# considering VERB
# in ADP
# her PRON
# own ADJ
# mind NOUN
# ( PUNCT
# as ADV
# well ADV
# as SCONJ
# she PRON
# could AUX
# , PUNCT
# for ADP
# the DET
#
#  SPACE
# hot ADJ
# day NOUN
# made VERB
# her PRON
# feel VERB
# very ADV
# sleepy ADJ
# and CCONJ
# stupid ADJ
# ) PUNCT
# , PUNCT
# whether SCONJ
# the DET
# pleasure NOUN
# of ADP
#
#  SPACE
# making VERB
# a DET
# daisy NOUN
# - PUNCT
# chain NOUN
# would AUX
# be AUX
# worth ADJ
# the DET
# trouble NOUN
# of ADP
# getting VERB
# up ADP
# and CCONJ
#
#  SPACE
# picking VERB
# the DET
# daisies NOUN
# , PUNCT
# when SCONJ
# suddenly ADV
# a DET
# White PROPN
# Rabbit PROPN
# with ADP
# pink ADJ
# eyes NOUN
# ran VERB
#
#  SPACE
# close ADJ
# by ADP
# her PRON
# . PUNCT
#
#
#  SPACE
# There PRON
# was VERB
# nothing PRON
# so ADV
# _ ADV
# very ADV
# _ ADV
# remarkable ADJ
# in ADP
# that PRON
# ; PUNCT
# nor CCONJ
# did AUX
# Alice PROPN
# think VERB
# it PRON
#
#  SPACE
# so ADV
# _ ADV
# very ADV
# _ ADV
# much ADV
# out ADP
# of ADP
# the DET
# way NOUN
# to PART
# hear VERB
# the DET
# Rabbit PROPN
# say VERB
# to ADP
# itself PRON
# , PUNCT
# âOh PROPN
#
#  SPACE
# dear NOUN
# ! PUNCT
# Oh INTJ
# dear INTJ
# ! PUNCT
# I PRON
# shall AUX
# be AUX
# late!â ADJ
# ( PUNCT
# when SCONJ
# she PRON
# thought VERB
# it PRON
# over ADP
# afterwards ADV
# , PUNCT
#
#  SPACE
# it PRON
# occurred VERB
# to ADP
# her PRON
# that SCONJ
# she PRON
# ought AUX
# to PART
# have AUX
# wondered VERB
# at ADP
# this PRON
# , PUNCT
# but CCONJ
# at ADP
# the DET
#
#  SPACE
# time NOUN
# it PRON
# all PRON
# seemed VERB
# quite ADV
# natural ADJ
# ) PUNCT
# ; PUNCT
# but CCONJ
# when SCONJ
# the DET
# Rabbit PROPN
# actually ADV
# _ PRON
# took VERB
# a DET
#
#  SPACE
# watch NOUN
# out ADP
# of ADP
# its PRON
# waistcoat NOUN
# - PUNCT
# pocket NOUN
# _ NOUN
# , PUNCT
# and CCONJ
# looked VERB
# at ADP
# it PRON
# , PUNCT
# and CCONJ
# then ADV
# hurried VERB
#
#  SPACE
# on ADP
# , PUNCT
# Alice PROPN
# started VERB
# to ADP
# her PRON
# feet NOUN
# , PUNCT
# for SCONJ
# it PRON
# flashed VERB
# across ADP
# her PRON
# mind NOUN
# that SCONJ
# she PRON
#
#  SPACE
# had AUX
# never ADV
# before ADV
# seen VERB
# a DET
# rabbit NOUN
# with ADP
# either CCONJ
# a DET
# waistcoat NOUN
# - PUNCT
# pocket NOUN
# , PUNCT
# or CCONJ
# a DET
#
#  SPACE
# watch NOUN
# to PART
# take VERB
# out ADP
# of ADP
# it PRON
# , PUNCT
# and CCONJ
# burning VERB
# with ADP
# curiosity NOUN
# , PUNCT
# she PRON
# ran VERB
# across ADP
# the DET
#
#  SPACE
# field NOUN
# after ADP
# it PRON
# , PUNCT
# and CCONJ
# fortunately ADV
# was AUX
# just ADV
# in ADP
# time NOUN
# to PART
# see VERB
# it PRON
# pop VERB
# down ADP
# a DET
#
#  SPACE
# large ADJ
# rabbit NOUN
# - PUNCT
# hole NOUN
# under ADP
# the DET
# hedge NOUN
# . PUNCT
#
#
#  SPACE
# In ADP
# another DET
# moment NOUN
# down ADV
# went VERB
# Alice PROPN
# after ADP
# it PRON
# , PUNCT
# never ADV
# once ADV
# considering VERB
# how SCONJ
#
#  SPACE
# in ADP
# the DET
# world NOUN
# she PRON
# was AUX
# to PART
# get VERB
# out ADP
# again ADV
# . PUNCT
#
#
#  SPACE
# The DET
# rabbit NOUN
# - PUNCT
# hole NOUN
# went VERB
# straight ADV
# on ADV
# like ADP
# a DET
# tunnel NOUN
# for ADP
# some DET
# way NOUN
# , PUNCT
# and CCONJ
# then ADV
#
#  SPACE
# dipped VERB
# suddenly ADV
# down ADV
# , PUNCT
# so ADV
# suddenly ADV
# that SCONJ
# Alice PROPN
# had VERB
# not PART
# a DET
# moment NOUN
# to PART
# think VERB
#
#  SPACE
# about ADP
# stopping VERB
# herself PRON
# before SCONJ
# she PRON
# found VERB
# herself PRON
# falling VERB
# down ADP
# a DET
# very ADV
#
#  SPACE
# deep ADJ
# well ADV
# . PUNCT
#
#
#  SPACE
# Either CCONJ
# the DET
# well NOUN
# was AUX
# very ADV
# deep ADJ
# , PUNCT
# or CCONJ
# she PRON
# fell VERB
# very ADV
# slowly ADV
# , PUNCT
# for SCONJ
# she PRON
# had VERB
#
#  SPACE
# plenty NOUN
# of ADP
# time NOUN
# as SCONJ
# she PRON
# went VERB
# down ADP
# to PART
# look VERB
# about ADP
# her PRON
# and CCONJ
# to PART
# wonder VERB
# what PRON
#
#  SPACE
# was AUX
# going VERB
# to PART
# happen VERB
# next ADV
# . PUNCT
# First ADV
# , PUNCT
# she PRON
# tried VERB
# to PART
# look VERB
# down ADP
# and CCONJ
# make VERB
# out ADP
#
#  SPACE
# what PRON
# she PRON
# was AUX
# coming VERB
# to ADP
# , PUNCT
# but CCONJ
# it PRON
# was AUX
# too ADV
# dark ADJ
# to PART
# see VERB
# anything PRON
# ; PUNCT
# then ADV
# she PRON
#
#  SPACE
# looked VERB
# at ADP
# the DET
# sides NOUN
# of ADP
# the DET
# well NOUN
# , PUNCT
# and CCONJ
# noticed VERB
# that SCONJ
# they PRON
# were AUX
# filled VERB
# with ADP
#
#  SPACE
# cupboards NOUN
# and CCONJ
# book NOUN
# - PUNCT
# shelves NOUN
# ; PUNCT
# here ADV
# and CCONJ
# there ADV
# she PRON
# saw VERB
# maps NOUN
# and CCONJ
# pictures NOUN
#
#  SPACE
# hung VERB
# upon SCONJ
# pegs NOUN
# . PUNCT
# She PRON
# took VERB
# down ADP
# a DET
# jar NOUN
# from ADP
# one NUM
# of ADP
# the DET
# shelves NOUN
# as SCONJ
# she PRON
#
#  SPACE
# passed VERB
# ; PUNCT
# it PRON
# was AUX
# labelled VERB
# âORANGE PROPN
# MARMALADEâ PROPN
# , PUNCT
# but CCONJ
# to ADP
# her PRON
# great ADJ
#
#  SPACE
# disappointment NOUN
# it PRON
# was AUX
# empty ADJ
# : PUNCT
# she PRON
# did AUX
# not PART
# like VERB
# to PART
# drop VERB
# the DET
# jar NOUN
# for ADP
# fear NOUN
#
#  SPACE
# of ADP
# killing VERB
# somebody PRON
# underneath ADV
# , PUNCT
# so ADV
# managed VERB
# to PART
# put VERB
# it PRON
# into ADP
# one NUM
# of ADP
# the DET
#
#  SPACE
# cupboards NOUN
# as SCONJ
# she PRON
# fell VERB
# past ADP
# it PRON
# . PUNCT
#
#
#  SPACE
# âWell!â NUM
# thought VERB
# Alice PROPN
# to ADP
# herself PRON
# , PUNCT
# âafter VERB
# such DET
# a DET
# fall NOUN
# as ADP
# this PRON
# , PUNCT
# I PRON
# shall AUX
#
#  SPACE
# think VERB
# nothing PRON
# of ADP
# tumbling VERB
# down ADP
# stairs NOUN
# ! PUNCT
# How SCONJ
# brave ADJ
# theyâll NOUN
# all PRON
# think VERB
# me PRON
#
#  SPACE
# at ADP
# home NOUN
# ! PUNCT
# Why SCONJ
# , PUNCT
# I PRON
# wouldnât AUX
# say VERB
# anything PRON
# about ADP
# it PRON
# , PUNCT
# even ADV
# if SCONJ
# I PRON
# fell VERB
# off ADP
# the DET
#
#  SPACE
# top NOUN
# of ADP
# the DET
# house!â NOUN
# ( PUNCT
# Which PRON
# was AUX
# very ADV
# likely ADJ
# true ADJ
# . PUNCT
# ) PUNCT
#
#
#  SPACE
# Down ADV
# , PUNCT
# down ADV
# , PUNCT
# down ADV
# . PUNCT
# Would AUX
# the DET
# fall NOUN
# _ ADV
# never ADV
# _ PROPN
# come VERB
# to ADP
# an DET
# end NOUN
# ? PUNCT
# âI PRON
# wonder VERB
# how SCONJ
#
#  SPACE
# many ADJ
# miles NOUN
# Iâve NUM
# fallen VERB
# by ADP
# this DET
# time?â NOUN
# she PRON
# said VERB
# aloud ADV
# . PUNCT
# âI X
# must AUX
# be AUX
#
#  SPACE
# getting VERB
# somewhere ADV
# near ADP
# the DET
# centre NOUN
# of ADP
# the DET
# earth NOUN
# . PUNCT
# Let VERB
# me PRON
# see VERB
# : PUNCT
# that PRON
# would AUX
#
#  SPACE
# be AUX
# four NUM
# thousand NUM
# miles NOUN
# down ADV
# , PUNCT
# I PRON
# thinkââ AUX
# ( PUNCT
# for ADP
# , PUNCT
# you PRON
# see VERB
# , PUNCT
# Alice PROPN
# had AUX
# learnt VERB
#
#  SPACE
# several ADJ
# things NOUN
# of ADP
# this DET
# sort NOUN
# in ADP
# her PRON
# lessons NOUN
# in ADP
# the DET
# schoolroom NOUN
# , PUNCT
# and CCONJ
#
#  SPACE
# though SCONJ
# this PRON
# was AUX
# not PART
# a DET
# _ NOUN
# very ADV
# _ PRON
# good ADJ
# opportunity NOUN
# for ADP
# showing VERB
# off ADP
# her PRON
#
#  SPACE
# knowledge NOUN
# , PUNCT
# as SCONJ
# there PRON
# was VERB
# no DET
# one NOUN
# to PART
# listen VERB
# to ADP
# her PRON
# , PUNCT
# still ADV
# it PRON
# was AUX
# good ADJ
#
#  SPACE
# practice NOUN
# to PART
# say VERB
# it PRON
# over ADP
# ) PUNCT
# ââyes PROPN
# , PUNCT
# thatâs VERB
# about ADP
# the DET
# right ADJ
# distanceâbut NOUN
#
#  SPACE
# then ADV
# I PRON
# wonder VERB
# what PRON
# Latitude PROPN
# or CCONJ
# Longitude PROPN
# Iâve NUM
# got VERB
# to?â NOUN
# ( PUNCT
# Alice PROPN
# had VERB
# no DET
#
#  SPACE
# idea NOUN
# what PRON
# Latitude PROPN
# was AUX
# , PUNCT
# or CCONJ
# Longitude PROPN
# either ADV
# , PUNCT
# but CCONJ
# thought VERB
# they PRON
# were AUX
# nice ADJ
#
#  SPACE
# grand ADJ
# words NOUN
# to PART
# say VERB
# . PUNCT
# ) PUNCT
#
#
#  SPACE
# Presently ADV
# she PRON
# began VERB
# again ADV
# . PUNCT
# âI PRON
# wonder NOUN
# if SCONJ
# I PRON
# shall AUX
# fall VERB
# right ADV
# _ ADV
# through ADP
# _ PROPN
#
#  SPACE
# the DET
# earth NOUN
# ! PUNCT
# How SCONJ
# funny ADJ
# itâll NOUN
# seem VERB
# to PART
# come VERB
# out ADP
# among ADP
# the DET
# people NOUN
# that PRON
# walk VERB
#
#  SPACE
# with ADP
# their PRON
# heads NOUN
# downward ADV
# ! PUNCT
# The DET
# Antipathies PROPN
# , PUNCT
# I PRON
# thinkââ AUX
# ( PUNCT
# she PRON
# was AUX
# rather ADV
#
#  SPACE
# glad ADJ
# there PRON
# _ NOUN
# was AUX
# _ NOUN
# no DET
# one NOUN
# listening VERB
# , PUNCT
# this DET
# time NOUN
# , PUNCT
# as SCONJ
# it PRON
# didnât NUM
# sound VERB
# at ADV
# all ADV
#
#  SPACE
# the DET
# right ADJ
# word NOUN
# ) PUNCT
# ââbut PROPN
# I PRON
# shall AUX
# have VERB
# to PART
# ask VERB
# them PRON
# what PRON
# the DET
# name NOUN
# of ADP
# the DET
#
#  SPACE
# country NOUN
# is AUX
# , PUNCT
# you PRON
# know VERB
# . PUNCT
# Please INTJ
# , PUNCT
# Maâam PROPN
# , PUNCT
# is AUX
# this DET
# New PROPN
# Zealand PROPN
# or CCONJ
# Australia?â PROPN
#
#  SPACE
# ( PUNCT
# and CCONJ
# she PRON
# tried VERB
# to PART
# curtsey VERB
# as SCONJ
# she PRON
# spokeâfancy VERB
# _ PUNCT
# curtseying VERB
# _ NOUN
# as SCONJ
# youâre PROPN
#
#  SPACE
# falling VERB
# through ADP
# the DET
# air NOUN
# ! PUNCT
# Do AUX
# you PRON
# think VERB
# you PRON
# could AUX
# manage VERB
# it PRON
# ? PUNCT
# ) PUNCT
# âAnd NOUN
# what PRON
#
#  SPACE
# an DET
# ignorant ADJ
# little ADJ
# girl NOUN
# sheâll NOUN
# think VERB
# me PRON
# for ADP
# asking VERB
# ! PUNCT
# No INTJ
# , PUNCT
# itâll NOUN
# never ADV
# do VERB
#
#  SPACE
# to PART
# ask VERB
# : PUNCT
# perhaps ADV
# I PRON
# shall AUX
# see VERB
# it PRON
# written VERB
# up ADP
# somewhere.â PROPN
#
#
#  SPACE
# Down ADP
# , PUNCT
# down ADV
# , PUNCT
# down ADV
# . PUNCT
# There PRON
# was VERB
# nothing PRON
# else ADV
# to PART
# do VERB
# , PUNCT
# so ADV
# Alice PROPN
# soon ADV
# began VERB
#
#  SPACE
# talking VERB
# again ADV
# . PUNCT
# âDinahâll NOUN
# miss VERB
# me PRON
# very ADV
# much ADV
# to ADP
# - PUNCT
# night NOUN
# , PUNCT
# I PRON
# should AUX
# think!â VERB
#
#  SPACE
# ( PUNCT
# Dinah PROPN
# was AUX
# the DET
# cat NOUN
# . PUNCT
# ) PUNCT
# âI X
# hope VERB
# theyâll PROPN
# remember VERB
# her PRON
# saucer NOUN
# of ADP
# milk NOUN
# at ADP
#
#  SPACE
# tea NOUN
# - PUNCT
# time NOUN
# . PUNCT
# Dinah PROPN
# my PRON
# dear NOUN
# ! PUNCT
# I PRON
# wish VERB
# you PRON
# were AUX
# down ADV
# here ADV
# with ADP
# me PRON
# ! PUNCT
# There PRON
# are VERB
#
#  SPACE
# no DET
# mice NOUN
# in ADP
# the DET
# air NOUN
# , PUNCT
# Iâm NOUN
# afraid ADJ
# , PUNCT
# but CCONJ
# you PRON
# might AUX
# catch VERB
# a DET
# bat NOUN
# , PUNCT
# and CCONJ
# thatâs NOUN
#
#  SPACE
# very ADV
# like ADP
# a DET
# mouse NOUN
# , PUNCT
# you PRON
# know VERB
# . PUNCT
# But CCONJ
# do AUX
# cats NOUN
# eat VERB
# bats NOUN
# , PUNCT
# I PRON
# wonder?â PROPN
# And CCONJ
# here ADV
#
#  SPACE
# Alice PROPN
# began VERB
# to PART
# get VERB
# rather ADV
# sleepy ADJ
# , PUNCT
# and CCONJ
# went VERB
# on ADP
# saying VERB
# to ADP
# herself PRON
# , PUNCT
# in ADP
# a DET
#
#  SPACE
# dreamy ADJ
# sort NOUN
# of ADP
# way NOUN
# , PUNCT
# âDo PROPN
# cats NOUN
# eat VERB
# bats NOUN
# ? PUNCT
# Do AUX
# cats NOUN
# eat VERB
# bats?â NOUN
# and CCONJ
#
#  SPACE
# sometimes ADV
# , PUNCT
# âDo PROPN
# bats NOUN
# eat VERB
# cats?â NOUN
# for ADP
# , PUNCT
# you PRON
# see VERB
# , PUNCT
# as SCONJ
# she PRON
# couldnât NUM
# answer NOUN
#
#  SPACE
# either DET
# question NOUN
# , PUNCT
# it PRON
# didnât NUM
# much ADV
# matter ADV
# which DET
# way NOUN
# she PRON
# put VERB
# it PRON
# . PUNCT
# She PRON
# felt VERB
#
#  SPACE
# that SCONJ
# she PRON
# was AUX
# dozing VERB
# off ADP
# , PUNCT
# and CCONJ
# had AUX
# just ADV
# begun VERB
# to PART
# dream VERB
# that SCONJ
# she PRON
# was AUX
#
#  SPACE
# walking VERB
# hand NOUN
# in ADP
# hand NOUN
# with ADP
# Dinah PROPN
# , PUNCT
# and CCONJ
# saying VERB
# to ADP
# her PRON
# very ADV
# earnestly ADV
# , PUNCT
#
#  SPACE
# âNow PROPN
# , PUNCT
# Dinah PROPN
# , PUNCT
# tell VERB
# me PRON
# the DET
# truth NOUN
# : PUNCT
# did AUX
# you PRON
# ever ADV
# eat VERB
# a DET
# bat?â NOUN
# when SCONJ
# suddenly ADV
# , PUNCT
#
#  SPACE
# thump NOUN
# ! PUNCT
# thump VERB
# ! PUNCT
# down ADV
# she PRON
# came VERB
# upon SCONJ
# a DET
# heap NOUN
# of ADP
# sticks NOUN
# and CCONJ
# dry ADJ
# leaves NOUN
# , PUNCT
# and CCONJ
#
#  SPACE
# the DET
# fall NOUN
# was AUX
# over ADV
# . PUNCT
#
#
#  SPACE
# Alice PROPN
# was AUX
# not PART
# a DET
# bit NOUN
# hurt ADJ
# , PUNCT
# and CCONJ
# she PRON
# jumped VERB
# up ADP
# on ADP
# to ADP
# her PRON
# feet NOUN
# in ADP
# a DET
# moment NOUN
# : PUNCT
#
#  SPACE
# she PRON
# looked VERB
# up ADP
# , PUNCT
# but CCONJ
# it PRON
# was AUX
# all PRON
# dark ADJ
# overhead ADV
# ; PUNCT
# before SCONJ
# her PRON
# was AUX
# another DET
#
#  SPACE
# long ADJ
# passage NOUN
# , PUNCT
# and CCONJ
# the DET
# White PROPN
# Rabbit PROPN
# was AUX
# still ADV
# in ADP
# sight NOUN
# , PUNCT
# hurrying VERB
# down ADP
#
#  SPACE
# it PRON
# . PUNCT
# There PRON
# was VERB
# not PART
# a DET
# moment NOUN
# to PART
# be AUX
# lost VERB
# : PUNCT
# away ADV
# went VERB
# Alice PROPN
# like ADP
# the DET
# wind NOUN
# , PUNCT
#
#  SPACE
# and CCONJ
# was AUX
# just ADV
# in ADP
# time NOUN
# to PART
# hear VERB
# it PRON
# say VERB
# , PUNCT
# as SCONJ
# it PRON
# turned VERB
# a DET
# corner NOUN
# , PUNCT
# âOh PROPN
# my PRON
# ears NOUN
#
#  SPACE
# and CCONJ
# whiskers NOUN
# , PUNCT
# how SCONJ
# late ADJ
# itâs PROPN
# getting!â NOUN
# She PRON
# was AUX
# close ADJ
# behind ADP
# it PRON
# when SCONJ
# she PRON
#
#  SPACE
# turned VERB
# the DET
# corner NOUN
# , PUNCT
# but CCONJ
# the DET
# Rabbit PROPN
# was AUX
# no ADV
# longer ADV
# to PART
# be AUX
# seen VERB
# : PUNCT
# she PRON
# found VERB
#
#  SPACE
# herself PRON
# in ADP
# a DET
# long ADJ
# , PUNCT
# low ADJ
# hall NOUN
# , PUNCT
# which PRON
# was AUX
# lit VERB
# up ADP
# by ADP
# a DET
# row NOUN
# of ADP
# lamps NOUN
# hanging VERB
#
#  SPACE
# from ADP
# the DET
# roof NOUN
# . PUNCT
#
#
#  SPACE
# There PRON
# were VERB
# doors NOUN
# all PRON
# round VERB
# the DET
# hall NOUN
# , PUNCT
# but CCONJ
# they PRON
# were AUX
# all ADV
# locked VERB
# ; PUNCT
# and CCONJ
# when SCONJ
#
#  SPACE
# Alice PROPN
# had AUX
# been AUX
# all DET
# the DET
# way NOUN
# down ADP
# one NUM
# side NOUN
# and CCONJ
# up ADP
# the DET
# other ADJ
# , PUNCT
# trying VERB
# every DET
#
#  SPACE
# door NOUN
# , PUNCT
# she PRON
# walked VERB
# sadly ADV
# down ADP
# the DET
# middle NOUN
# , PUNCT
# wondering VERB
# how SCONJ
# she PRON
# was AUX
# ever ADV
# to PART
#
#  SPACE
# get VERB
# out ADP
# again ADV
# . PUNCT
#
#
#  SPACE
# Suddenly ADV
# she PRON
# came VERB
# upon SCONJ
# a DET
# little ADJ
# three NUM
# - PUNCT
# legged ADJ
# table NOUN
# , PUNCT
# all PRON
# made VERB
# of ADP
# solid ADJ
#
#  SPACE
# glass NOUN
# ; PUNCT
# there PRON
# was VERB
# nothing PRON
# on ADP
# it PRON
# except SCONJ
# a DET
# tiny ADJ
# golden ADJ
# key NOUN
# , PUNCT
# and CCONJ
# Aliceâs NOUN
#
#  SPACE
# first ADJ
# thought NOUN
# was AUX
# that SCONJ
# it PRON
# might AUX
# belong VERB
# to ADP
# one NUM
# of ADP
# the DET
# doors NOUN
# of ADP
# the DET
# hall NOUN
# ; PUNCT
#
#  SPACE
# but CCONJ
# , PUNCT
# alas INTJ
# ! PUNCT
# either CCONJ
# the DET
# locks NOUN
# were AUX
# too ADV
# large ADJ
# , PUNCT
# or CCONJ
# the DET
# key NOUN
# was AUX
# too ADV
# small ADJ
# , PUNCT
#
#  SPACE
# but CCONJ
# at ADP
# any DET
# rate NOUN
# it PRON
# would AUX
# not PART
# open VERB
# any PRON
# of ADP
# them PRON
# . PUNCT
# However ADV
# , PUNCT
# on ADP
# the DET
# second ADJ
#
#  SPACE
# time NOUN
# round ADV
# , PUNCT
# she PRON
# came VERB
# upon SCONJ
# a DET
# low ADJ
# curtain NOUN
# she PRON
# had AUX
# not PART
# noticed VERB
# before ADV
# , PUNCT
# and CCONJ
#
#  SPACE
# behind ADP
# it PRON
# was AUX
# a DET
# little ADJ
# door NOUN
# about ADV
# fifteen NUM
# inches NOUN
# high ADJ
# : PUNCT
# she PRON
# tried VERB
# the DET
#
#  SPACE
# little ADJ
# golden ADJ
# key NOUN
# in ADP
# the DET
# lock NOUN
# , PUNCT
# and CCONJ
# to ADP
# her PRON
# great ADJ
# delight NOUN
# it PRON
# fitted VERB
# ! PUNCT
#
#
#  SPACE
# Alice PROPN
# opened VERB
# the DET
# door NOUN
# and CCONJ
# found VERB
# that SCONJ
# it PRON
# led VERB
# into ADP
# a DET
# small ADJ
# passage NOUN
# , PUNCT
# not PART
#
#  SPACE
# much ADV
# larger ADJ
# than ADP
# a DET
# rat NOUN
# - NOUN
# hole NOUN
# : PUNCT
# she PRON
# knelt VERB
# down ADP
# and CCONJ
# looked VERB
# along ADP
# the DET
#
#  SPACE
# passage NOUN
# into ADP
# the DET
# loveliest ADJ
# garden NOUN
# you PRON
# ever ADV
# saw VERB
# . PUNCT
# How SCONJ
# she PRON
# longed VERB
# to PART
# get VERB
#
#  SPACE
# out ADP
# of ADP
# that DET
# dark PROPN
# hall NOUN
# , PUNCT
# and CCONJ
# wander VERB
# about ADP
# among ADP
# those DET
# beds NOUN
# of ADP
# bright ADJ
#
#  SPACE
# flowers NOUN
# and CCONJ
# those DET
# cool ADJ
# fountains NOUN
# , PUNCT
# but CCONJ
# she PRON
# could AUX
# not PART
# even ADV
# get VERB
# her PRON
# head NOUN
#
#  SPACE
# through ADP
# the DET
# doorway NOUN
# ; PUNCT
# âand PUNCT
# even ADV
# if SCONJ
# my PRON
# head NOUN
# would AUX
# go VERB
# through ADV
# , PUNCT
# â PROPN
# thought VERB
#
#  SPACE
# poor ADJ
# Alice PROPN
# , PUNCT
# âit PROPN
# would AUX
# be AUX
# of ADP
# very ADV
# little ADJ
# use NOUN
# without ADP
# my PRON
# shoulders NOUN
# . PUNCT
# Oh INTJ
# , PUNCT
#
#  SPACE
# how SCONJ
# I PRON
# wish VERB
# I PRON
# could AUX
# shut VERB
# up ADP
# like ADP
# a DET
# telescope NOUN
# ! PUNCT
# I PRON
# think VERB
# I PRON
# could AUX
# , PUNCT
# if SCONJ
# I PRON
# only ADV
#
#  SPACE
# knew VERB
# how SCONJ
# to ADP
# begin.â NOUN
# For ADP
# , PUNCT
# you PRON
# see VERB
# , PUNCT
# so ADV
# many ADJ
# out ADP
# - PUNCT
# of ADP
# - PUNCT
# the DET
# - PUNCT
# way NOUN
# things NOUN
# had AUX
#
#  SPACE
# happened VERB
# lately ADV
# , PUNCT
# that SCONJ
# Alice PROPN
# had AUX
# begun VERB
# to PART
# think VERB
# that SCONJ
# very ADV
# few ADJ
# things NOUN
#
#  SPACE
# indeed ADV
# were AUX
# really ADV
# impossible ADJ
# . PUNCT
#
#
#  SPACE
# There PRON
# seemed VERB
# to PART
# be AUX
# no DET
# use NOUN
# in ADP
# waiting VERB
# by ADP
# the DET
# little ADJ
# door NOUN
# , PUNCT
# so ADV
# she PRON
# went VERB
#
#  SPACE
# back ADV
# to ADP
# the DET
# table NOUN
# , PUNCT
# half NOUN
# hoping VERB
# she PRON
# might AUX
# find VERB
# another DET
# key NOUN
# on ADP
# it PRON
# , PUNCT
# or CCONJ
# at ADP
#
#  SPACE
# any DET
# rate NOUN
# a DET
# book NOUN
# of ADP
# rules NOUN
# for ADP
# shutting VERB
# people NOUN
# up ADP
# like ADP
# telescopes NOUN
# : PUNCT
# this DET
#
#  SPACE
# time NOUN
# she PRON
# found VERB
# a DET
# little ADJ
# bottle NOUN
# on ADP
# it PRON
# , PUNCT
# ( PUNCT
# âwhich PROPN
# certainly ADV
# was AUX
# not PART
# here ADV
#
#  SPACE
# before ADV
# , PUNCT
# â PROPN
# said VERB
# Alice PROPN
# , PUNCT
# ) PUNCT
# and CCONJ
# round VERB
# the DET
# neck NOUN
# of ADP
# the DET
# bottle NOUN
# was AUX
# a DET
# paper NOUN
#
#  SPACE
# label NOUN
# , PUNCT
# with ADP
# the DET
# words NOUN
# âDRINK VERB
# ME PROPN
# , PUNCT
# â PROPN
# beautifully ADV
# printed VERB
# on ADP
# it PRON
# in ADP
# large ADJ
#
#  SPACE
# letters NOUN
# . PUNCT
#
#
#  SPACE
# It PRON
# was AUX
# all ADV
# very ADV
# well ADV
# to PART
# say VERB
# âDrink VERB
# me PRON
# , PUNCT
# â PROPN
# but CCONJ
# the DET
# wise ADJ
# little ADJ
# Alice PROPN
# was AUX
#
#  SPACE
# not PART
# going VERB
# to PART
# do VERB
# _ PRON
# that DET
# _ NOUN
# in ADP
# a DET
# hurry NOUN
# . PUNCT
# âNo PROPN
# , PUNCT
# Iâll NUM
# look VERB
# first ADV
# , PUNCT
# â PROPN
# she PRON
# said VERB
# , PUNCT
#
#  SPACE
# âand CCONJ
# see VERB
# whether SCONJ
# itâs PROPN
# marked VERB
# â_poison_â NOUN
# or CCONJ
# notâ NOUN
# ; PUNCT
# for SCONJ
# she PRON
# had AUX
# read VERB
#
#  SPACE
# several ADJ
# nice ADJ
# little ADJ
# histories NOUN
# about ADP
# children NOUN
# who PRON
# had AUX
# got AUX
# burnt VERB
# , PUNCT
# and CCONJ
#
#  SPACE
# eaten VERB
# up ADP
# by ADP
# wild ADJ
# beasts NOUN
# and CCONJ
# other ADJ
# unpleasant ADJ
# things NOUN
# , PUNCT
# all ADV
# because SCONJ
# they PRON
#
#  SPACE
# _ VERB
# would AUX
# _ PROPN
# not PART
# remember VERB
# the DET
# simple ADJ
# rules NOUN
# their PRON
# friends NOUN
# had AUX
# taught VERB
# them PRON
# : PUNCT
#
#  SPACE
# such ADJ
# as ADP
# , PUNCT
# that SCONJ
# a DET
# red ADJ
# - PUNCT
# hot ADJ
# poker NOUN
# will AUX
# burn VERB
# you PRON
# if SCONJ
# you PRON
# hold VERB
# it PRON
# too ADV
# long ADV
# ; PUNCT
#
#  SPACE
# and CCONJ
# that SCONJ
# if SCONJ
# you PRON
# cut VERB
# your PRON
# finger NOUN
# _ PROPN
# very ADV
# _ ADV
# deeply ADV
# with ADP
# a DET
# knife NOUN
# , PUNCT
# it PRON
# usually ADV
#
#  SPACE
# bleeds VERB
# ; PUNCT
# and CCONJ
# she PRON
# had AUX
# never ADV
# forgotten VERB
# that SCONJ
# , PUNCT
# if SCONJ
# you PRON
# drink VERB
# much ADV
# from ADP
# a DET
#
#  SPACE
# bottle NOUN
# marked VERB
# âpoison NOUN
# , PUNCT
# â PROPN
# it PRON
# is AUX
# almost ADV
# certain ADJ
# to PART
# disagree VERB
# with ADP
# you PRON
# , PUNCT
#
#  SPACE
# sooner ADV
# or CCONJ
# later ADV
# . PUNCT
#
#
#  SPACE
# However ADV
# , PUNCT
# this DET
# bottle NOUN
# was AUX
# _ PROPN
# not PART
# _ PROPN
# marked VERB
# âpoison PROPN
# , PUNCT
# â PROPN
# so ADV
# Alice PROPN
# ventured VERB
# to PART
#
#  SPACE
# taste VERB
# it PRON
# , PUNCT
# and CCONJ
# finding VERB
# it PRON
# very ADV
# nice ADJ
# , PUNCT
# ( PUNCT
# it PRON
# had AUX
# , PUNCT
# in ADP
# fact NOUN
# , PUNCT
# a DET
# sort NOUN
# of ADP
# mixed ADJ
#
#  SPACE
# flavour NOUN
# of ADP
# cherry NOUN
# - PUNCT
# tart NOUN
# , PUNCT
# custard NOUN
# , PUNCT
# pine NOUN
# - PUNCT
# apple NOUN
# , PUNCT
# roast NOUN
# turkey PROPN
# , PUNCT
# toffee NOUN
# , PUNCT
# and CCONJ
#
#  SPACE
# hot ADJ
# buttered VERB
# toast NOUN
# , PUNCT
# ) PUNCT
# she PRON
# very ADV
# soon ADV
# finished VERB
# it PRON
# off ADP
# . PUNCT
#
#
#  SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#
#
#      SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#
#
#  SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#
#
#
#  SPACE
# âWhat ADP
# a DET
# curious ADJ
# feeling!â NOUN
# said VERB
# Alice PROPN
# ; PUNCT
# âI PROPN
# must AUX
# be AUX
# shutting VERB
# up ADP
# like ADP
# a DET
#
#  SPACE
# telescope.â NOUN
#
#
#  SPACE
# And CCONJ
# so ADV
# it PRON
# was AUX
# indeed ADV
# : PUNCT
# she PRON
# was AUX
# now ADV
# only ADV
# ten NUM
# inches NOUN
# high ADJ
# , PUNCT
# and CCONJ
# her PRON
# face NOUN
#
#  SPACE
# brightened VERB
# up ADP
# at ADP
# the DET
# thought NOUN
# that SCONJ
# she PRON
# was AUX
# now ADV
# the DET
# right ADJ
# size NOUN
# for ADP
# going VERB
#
#  SPACE
# through ADP
# the DET
# little ADJ
# door NOUN
# into ADP
# that DET
# lovely ADJ
# garden NOUN
# . PUNCT
# First ADV
# , PUNCT
# however ADV
# , PUNCT
# she PRON
#
#  SPACE
# waited VERB
# for ADP
# a DET
# few ADJ
# minutes NOUN
# to PART
# see VERB
# if SCONJ
# she PRON
# was AUX
# going VERB
# to PART
# shrink VERB
# any PRON
# further ADV
# : PUNCT
#
#  SPACE
# she PRON
# felt VERB
# a DET
# little ADJ
# nervous ADJ
# about ADP
# this PRON
# ; PUNCT
# âfor SCONJ
# it PRON
# might AUX
# end VERB
# , PUNCT
# you PRON
# know VERB
# , PUNCT
# â PROPN
#
#  SPACE
# said VERB
# Alice PROPN
# to ADP
# herself PRON
# , PUNCT
# âin X
# my PRON
# going VERB
# out ADP
# altogether ADV
# , PUNCT
# like ADP
# a DET
# candle NOUN
# . PUNCT
# I PRON
#
#  SPACE
# wonder VERB
# what PRON
# I PRON
# should AUX
# be AUX
# like ADP
# then?â NOUN
# And CCONJ
# she PRON
# tried VERB
# to PART
# fancy VERB
# what PRON
# the DET
#
#  SPACE
# flame NOUN
# of ADP
# a DET
# candle NOUN
# is AUX
# like ADP
# after SCONJ
# the DET
# candle NOUN
# is AUX
# blown VERB
# out ADP
# , PUNCT
# for SCONJ
# she PRON
# could AUX
#
#  SPACE
# not PART
# remember VERB
# ever ADV
# having AUX
# seen VERB
# such DET
# a DET
# thing NOUN
# . PUNCT
#
#
#  SPACE
# After ADP
# a DET
# while NOUN
# , PUNCT
# finding VERB
# that SCONJ
# nothing PRON
# more ADV
# happened VERB
# , PUNCT
# she PRON
# decided VERB
# on ADP
# going VERB
#
#  SPACE
# into ADP
# the DET
# garden NOUN
# at ADP
# once ADV
# ; PUNCT
# but CCONJ
# , PUNCT
# alas INTJ
# for ADP
# poor ADJ
# Alice PROPN
# ! PUNCT
# when SCONJ
# she PRON
# got VERB
# to ADP
# the DET
#
#  SPACE
# door NOUN
# , PUNCT
# she PRON
# found VERB
# she PRON
# had AUX
# forgotten VERB
# the DET
# little ADJ
# golden ADJ
# key NOUN
# , PUNCT
# and CCONJ
# when SCONJ
# she PRON
#
#  SPACE
# went VERB
# back ADV
# to ADP
# the DET
# table NOUN
# for ADP
# it PRON
# , PUNCT
# she PRON
# found VERB
# she PRON
# could AUX
# not PART
# possibly ADV
# reach VERB
#
#  SPACE
# it PRON
# : PUNCT
# she PRON
# could AUX
# see VERB
# it PRON
# quite ADV
# plainly ADV
# through ADP
# the DET
# glass NOUN
# , PUNCT
# and CCONJ
# she PRON
# tried VERB
# her PRON
#
#  SPACE
# best ADJ
# to PART
# climb VERB
# up ADP
# one NUM
# of ADP
# the DET
# legs NOUN
# of ADP
# the DET
# table NOUN
# , PUNCT
# but CCONJ
# it PRON
# was AUX
# too ADV
# slippery ADJ
# ; PUNCT
#
#  SPACE
# and CCONJ
# when SCONJ
# she PRON
# had AUX
# tired VERB
# herself PRON
# out ADP
# with ADP
# trying VERB
# , PUNCT
# the DET
# poor ADJ
# little ADJ
# thing NOUN
#
#  SPACE
# sat VERB
# down ADP
# and CCONJ
# cried VERB
# . PUNCT
#
#
#  SPACE
# âCome VERB
# , PUNCT
# thereâs PRON
# no DET
# use NOUN
# in ADP
# crying VERB
# like ADP
# that!â PROPN
# said VERB
# Alice PROPN
# to ADP
# herself PRON
# , PUNCT
#
#  SPACE
# rather ADV
# sharply ADV
# ; PUNCT
# âI X
# advise VERB
# you PRON
# to PART
# leave VERB
# off ADP
# this DET
# minute!â NOUN
# She PRON
# generally ADV
#
#  SPACE
# gave VERB
# herself PRON
# very ADV
# good ADJ
# advice NOUN
# , PUNCT
# ( PUNCT
# though SCONJ
# she PRON
# very ADV
# seldom ADV
# followed VERB
# it PRON
# ) PUNCT
# , PUNCT
#
#  SPACE
# and CCONJ
# sometimes ADV
# she PRON
# scolded VERB
# herself PRON
# so ADV
# severely ADV
# as SCONJ
# to PART
# bring VERB
# tears NOUN
# into ADP
#
#  SPACE
# her PRON
# eyes NOUN
# ; PUNCT
# and CCONJ
# once SCONJ
# she PRON
# remembered VERB
# trying VERB
# to PART
# box VERB
# her PRON
# own ADJ
# ears NOUN
# for ADP
# having AUX
#
#  SPACE
# cheated VERB
# herself PRON
# in ADP
# a DET
# game NOUN
# of ADP
# croquet NOUN
# she PRON
# was AUX
# playing VERB
# against ADP
# herself PRON
# , PUNCT
#
#  SPACE
# for ADP
# this DET
# curious ADJ
# child NOUN
# was AUX
# very ADV
# fond ADJ
# of ADP
# pretending VERB
# to PART
# be AUX
# two NUM
# people NOUN
# . PUNCT
#
#  SPACE
# âBut PROPN
# itâs PROPN
# no DET
# use NOUN
# now ADV
# , PUNCT
# â PROPN
# thought VERB
# poor ADJ
# Alice PROPN
# , PUNCT
# âto NOUN
# pretend VERB
# to PART
# be AUX
# two NUM
#
#  SPACE
# people NOUN
# ! PUNCT
# Why SCONJ
# , PUNCT
# thereâs PRON
# hardly ADV
# enough ADJ
# of ADP
# me PRON
# left VERB
# to PART
# make VERB
# _ PRON
# one NUM
# _ NOUN
# respectable ADJ
#
#  SPACE
# person!â NOUN
#
#
#  SPACE
# Soon ADV
# her PRON
# eye NOUN
# fell VERB
# on ADP
# a DET
# little ADJ
# glass NOUN
# box NOUN
# that PRON
# was AUX
# lying VERB
# under ADP
# the DET
# table NOUN
# : PUNCT
#
#  SPACE
# she PRON
# opened VERB
# it PRON
# , PUNCT
# and CCONJ
# found VERB
# in ADP
# it PRON
# a DET
# very ADV
# small ADJ
# cake NOUN
# , PUNCT
# on ADP
# which PRON
# the DET
# words NOUN
#
#  SPACE
# âEAT PROPN
# MEâ NOUN
# were AUX
# beautifully ADV
# marked VERB
# in ADP
# currants NOUN
# . PUNCT
# âWell ADJ
# , PUNCT
# Iâll PUNCT
# eat VERB
# it PRON
# , PUNCT
# â PROPN
# said VERB
#
#  SPACE
# Alice PROPN
# , PUNCT
# âand PUNCT
# if SCONJ
# it PRON
# makes VERB
# me PRON
# grow VERB
# larger ADJ
# , PUNCT
# I PRON
# can AUX
# reach VERB
# the DET
# key NOUN
# ; PUNCT
# and CCONJ
# if SCONJ
# it PRON
#
#  SPACE
# makes VERB
# me PRON
# grow VERB
# smaller ADJ
# , PUNCT
# I PRON
# can AUX
# creep VERB
# under ADP
# the DET
# door NOUN
# ; PUNCT
# so ADV
# either DET
# way NOUN
# Iâll PRON
#
#  SPACE
# get VERB
# into ADP
# the DET
# garden NOUN
# , PUNCT
# and CCONJ
# I PRON
# donât NUM
# care NOUN
# which DET
# happens!â PROPN
#
#
#  SPACE
# She PRON
# ate VERB
# a DET
# little ADJ
# bit NOUN
# , PUNCT
# and CCONJ
# said VERB
# anxiously ADV
# to ADP
# herself PRON
# , PUNCT
# âWhich PROPN
# way NOUN
# ? PUNCT
# Which DET
#
#  SPACE
# way?â NOUN
# , PUNCT
# holding VERB
# her PRON
# hand NOUN
# on ADP
# the DET
# top NOUN
# of ADP
# her PRON
# head NOUN
# to PART
# feel VERB
# which DET
# way NOUN
# it PRON
# was AUX
#
#  SPACE
# growing VERB
# , PUNCT
# and CCONJ
# she PRON
# was AUX
# quite ADV
# surprised ADJ
# to PART
# find VERB
# that SCONJ
# she PRON
# remained VERB
# the DET
# same ADJ
#
#  SPACE
# size NOUN
# : PUNCT
# to PART
# be AUX
# sure ADJ
# , PUNCT
# this PRON
# generally ADV
# happens VERB
# when SCONJ
# one PRON
# eats VERB
# cake NOUN
# , PUNCT
# but CCONJ
# Alice PROPN
#
#  SPACE
# had AUX
# got VERB
# so ADV
# much ADV
# into ADP
# the DET
# way NOUN
# of ADP
# expecting VERB
# nothing PRON
# but CCONJ
# out ADP
# - PUNCT
# of ADP
# - PUNCT
# the DET
# - PUNCT
# way NOUN
#
#  SPACE
# things NOUN
# to PART
# happen VERB
# , PUNCT
# that SCONJ
# it PRON
# seemed VERB
# quite ADV
# dull ADJ
# and CCONJ
# stupid ADJ
# for ADP
# life NOUN
# to PART
# go VERB
#
#  SPACE
# on ADP
# in ADP
# the DET
# common ADJ
# way NOUN
# . PUNCT
#
#
#  SPACE
# So ADV
# she PRON
# set VERB
# to PART
# work NOUN
# , PUNCT
# and CCONJ
# very ADV
# soon ADV
# finished VERB
# off ADP
# the DET
# cake NOUN
# . PUNCT
#
#
#  SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#
#
#      SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#
#
#  SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * PUNCT
#       SPACE
# * NOUN
#
#
#
#
#
#  SPACE
# CHAPTER PROPN
# II PROPN
# . PUNCT
#
#  SPACE
# The DET
# Pool PROPN
# of ADP
# Tears PROPN
#
#
#
#  SPACE
# âCuriouser NOUN
# and CCONJ
# curiouser!â NOUN
# cried VERB
# Alice PROPN
# ( PUNCT
# she PRON
# was AUX
# so ADV
# much ADV
# surprised ADJ
# , PUNCT
# that SCONJ
#
#  SPACE
# for ADP
# the DET
# moment NOUN
# she PRON
# quite ADV
# forgot VERB
# how SCONJ
# to PART
# speak VERB
# good ADJ
# English PROPN
# ) PUNCT
# ; PUNCT
# ânow PROPN
# Iâm NOUN
#
#  SPACE
# opening VERB
# out ADP
# like ADP
# the DET
# largest ADJ
# telescope NOUN
# that PRON
# ever ADV
# was AUX
# ! PUNCT
# Good ADJ
# - PUNCT
# bye PROPN
# , PUNCT
# feet!â NOUN
#
#  SPACE
# ( PUNCT
# for ADP
# when SCONJ
# she PRON
# looked VERB
# down ADP
# at ADP
# her PRON
# feet NOUN
# , PUNCT
# they PRON
# seemed VERB
# to PART
# be AUX
# almost ADV
# out ADP
# of ADP
#
#  SPACE
# sight NOUN
# , PUNCT
# they PRON
# were AUX
# getting VERB
# so ADV
# far ADV
# off ADV
# ) PUNCT
# . PUNCT
# âOh ADV
# , PUNCT
# my PRON
# poor ADJ
# little ADJ
# feet NOUN
# , PUNCT
# I PRON
#
#  SPACE
# wonder VERB
# who PRON
# will AUX
# put VERB
# on ADP
# your PRON
# shoes NOUN
# and CCONJ
# stockings NOUN
# for ADP
# you PRON
# now ADV
# , PUNCT
# dears VERB
# ? PUNCT
# Iâm ADV
#
#  SPACE
# sure ADJ
# _ PUNCT
# I PRON
# _ ADV
# shanât ADV
# be AUX
# able ADJ
# ! PUNCT
# I PRON
# shall AUX
# be AUX
# a DET
# great ADJ
# deal NOUN
# too ADV
# far ADV
# off ADP
# to ADP
# trouble NOUN
#
#  SPACE
# myself PRON
# about ADP
# you PRON
# : PUNCT
# you PRON
# must AUX
# manage VERB
# the DET
# best ADJ
# way NOUN
# you PRON
# can;âbut CCONJ
# I PRON
# must AUX
# be AUX
#
#  SPACE
# kind ADJ
# to ADP
# them PRON
# , PUNCT
# â PROPN
# thought VERB
# Alice PROPN
# , PUNCT
# âor PROPN
# perhaps ADV
# they PRON
# wonât NOUN
# walk VERB
# the DET
# way NOUN
# I PRON
#
#  SPACE
# want VERB
# to PART
# go VERB
# ! PUNCT
# Let VERB
# me PRON
# see VERB
# : PUNCT
# Iâll PUNCT
# give VERB
# them PRON
# a DET
# new ADJ
# pair NOUN
# of ADP
# boots NOUN
# every DET
#
#  SPACE
# Christmas.â NOUN
#
#
#  SPACE
# And CCONJ
# she PRON
# went VERB
# on ADP
# planning VERB
# to ADP
# herself PRON
# how SCONJ
# she PRON
# would AUX
# manage VERB
# it PRON
# . PUNCT
# âThey PRON
# must AUX
#
#  SPACE
# go VERB
# by ADP
# the DET
# carrier NOUN
# , PUNCT
# â PROPN
# she PRON
# thought VERB
# ; PUNCT
# âand CCONJ
# how SCONJ
# funny ADJ
# itâll NOUN
# seem VERB
# , PUNCT
# sending VERB
#
#  SPACE
# presents VERB
# to PART
# oneâs VERB
# own ADJ
# feet NOUN
# ! PUNCT
# And CCONJ
# how SCONJ
# odd ADJ
# the DET
# directions NOUN
# will AUX
# look VERB
# ! PUNCT
#
#
#       SPACE
# _ PUNCT
# Aliceâs PUNCT
# Right PROPN
# Foot PROPN
# , PUNCT
# Esq PROPN
# . PROPN
# , PUNCT
# Hearthrug PROPN
# , PUNCT
# near ADP
# the DET
# Fender PROPN
# , PUNCT
# _ NOUN
# ( PUNCT
# _ NOUN
# with ADP
#
#       SPACE
# Aliceâs PROPN
# love PROPN
# _ PROPN
# ) PUNCT
# . PUNCT
#
#
#  SPACE
# Oh INTJ
# dear ADJ
# , PUNCT
# what DET
# nonsense NOUN
# Iâm NOUN
# talking!â NOUN
#
#
#  SPACE
# Just ADV
# then ADV
# her PRON
# head NOUN
# struck VERB
# against ADP
# the DET
# roof NOUN
# of ADP
# the DET
# hall NOUN
# : PUNCT
# in ADP
# fact NOUN
# she PRON
# was AUX
#
#  SPACE
# now ADV
# more ADJ
# than ADP
# nine NUM
# feet NOUN
# high ADJ
# , PUNCT
# and CCONJ
# she PRON
# at ADP
# once ADV
# took VERB
# up ADP
# the DET
# little ADJ
# golden ADJ
#
#  SPACE
# key NOUN
# and CCONJ
# hurried VERB
# off ADP
# to ADP
# the DET
# garden NOUN
# door NOUN
# . PUNCT
#
#
#  SPACE
# Poor PROPN
# Alice PROPN
# ! PUNCT
# It PRON
# was AUX
# as ADV
# much ADV
# as SCONJ
# she PRON
# could AUX
# do VERB
# , PUNCT
# lying VERB
# down ADP
# on ADP
# one NUM
# side NOUN
# , PUNCT
# to PART
#
#  SPACE
# look VERB
# through ADP
# into ADP
# the DET
# garden NOUN
# with ADP
# one NUM
# eye NOUN
# ; PUNCT
# but CCONJ
# to PART
# get VERB
# through ADP
# was AUX
# more ADV
#
#  SPACE
# hopeless ADJ
# than ADP
# ever ADV
# : PUNCT
# she PRON
# sat VERB
# down ADP
# and CCONJ
# began VERB
# to PART
# cry VERB
# again ADV
# . PUNCT
#
#
#  SPACE
# âYou NOUN
# ought AUX
# to PART
# be AUX
# ashamed ADJ
# of ADP
# yourself PRON
# , PUNCT
# â PROPN
# said VERB
# Alice PROPN
# , PUNCT
# âa ADP
# great ADJ
# girl NOUN
# like ADP
#
#  SPACE
# you PRON
# , PUNCT
# â PROPN
# ( PUNCT
# she PRON
# might AUX
# well ADV
# say VERB
# this PRON
# ) PUNCT
# , PUNCT
# âto NOUN
# go VERB
# on ADP
# crying VERB
# in ADP
# this DET
# way NOUN
# ! PUNCT
# Stop VERB
#
#  SPACE
# this DET
# moment NOUN
# , PUNCT
# I PRON
# tell VERB
# you!â PROPN
# But CCONJ
# she PRON
# went VERB
# on ADP
# all DET
# the DET
# same ADJ
# , PUNCT
# shedding VERB
#
#  SPACE
# gallons NOUN
# of ADP
# tears NOUN
# , PUNCT
# until SCONJ
# there PRON
# was VERB
# a DET
# large ADJ
# pool NOUN
# all PRON
# round VERB
# her PRON
# , PUNCT
# about ADV
#
#  SPACE
# four NUM
# inches NOUN
# deep ADJ
# and CCONJ
# reaching VERB
# half NOUN
# down ADP
# the DET
# hall NOUN
# . PUNCT
#
#
#  SPACE
# After ADP
# a DET
# time NOUN
# she PRON
# heard VERB
# a DET
# little ADJ
# pattering ADJ
# of ADP
# feet NOUN
# in ADP
# the DET
# distance NOUN
# , PUNCT
# and CCONJ
#
#  SPACE
# she PRON
# hastily ADV
# dried VERB
# her PRON
# eyes NOUN
# to PART
# see VERB
# what PRON
# was AUX
# coming VERB
# . PUNCT
# It PRON
# was AUX
# the DET
# White PROPN
#
#  SPACE
# Rabbit NOUN
# returning VERB
# , PUNCT
# splendidly ADV
# dressed VERB
# , PUNCT
# with ADP
# a DET
# pair NOUN
# of ADP
# white ADJ
# kid NOUN
# gloves NOUN
#
#  SPACE
# in ADP
# one NUM
# hand NOUN
# and CCONJ
# a DET
# large ADJ
# fan NOUN
# in ADP
# the DET
# other ADJ
# : PUNCT
# he PRON
# came AUX
# trotting VERB
# along ADP
# in ADP
# a DET
#
#  SPACE
# great ADJ
# hurry NOUN
# , PUNCT
# muttering VERB
# to ADP
# himself PRON
# as SCONJ
# he PRON
# came VERB
# , PUNCT
# âOh PROPN
# ! PUNCT
# the DET
# Duchess PROPN
# , PUNCT
# the DET
#
#  SPACE
# Duchess PROPN
# ! PUNCT
# Oh INTJ
# ! PROPN
# wonât NOUN
# she PRON
# be VERB
# savage ADJ
# if SCONJ
# Iâve NUM
# kept VERB
# her PRON
# waiting!â NOUN
# Alice PROPN
# felt VERB
#
#  SPACE
# so ADV
# desperate ADJ
# that SCONJ
# she PRON
# was AUX
# ready ADJ
# to PART
# ask VERB
# help NOUN
# of ADP
# any DET
# one NOUN
# ; PUNCT
# so ADV
# , PUNCT
# when SCONJ
# the DET
#
#  SPACE
# Rabbit PROPN
# came VERB
# near ADP
# her PRON
# , PUNCT
# she PRON
# began VERB
# , PUNCT
# in ADP
# a DET
# low ADJ
# , PUNCT
# timid ADJ
# voice NOUN
# , PUNCT
# âIf PROPN
# you PRON
# please INTJ
# , PUNCT
#
#  SPACE
# sirââ X
# The DET
# Rabbit PROPN
# started VERB
# violently ADV
# , PUNCT
# dropped VERB
# the DET
# white ADJ
# kid NOUN
# gloves NOUN
# and CCONJ
#
#  SPACE
# the DET
# fan NOUN
# , PUNCT
# and CCONJ
# skurried VERB
# away ADV
# into ADP
# the DET
# darkness NOUN
# as ADV
# hard ADV
# as SCONJ
# he PRON
# could AUX
# go VERB
# . PUNCT
#
#
#  SPACE
# Alice PROPN
# took VERB
# up ADP
# the DET
# fan NOUN
# and CCONJ
# gloves NOUN
# , PUNCT
# and CCONJ
# , PUNCT
# as SCONJ
# the DET
# hall NOUN
# was AUX
# very ADV
# hot ADJ
# , PUNCT
# she PRON
#
#  SPACE
# kept VERB
# fanning VERB
# herself PRON
# all DET
# the DET
# time NOUN
# she PRON
# went VERB
# on ADP
# talking VERB
# : PUNCT
# âDear NOUN
# , PUNCT
# dear ADJ
# ! PUNCT
# How SCONJ
#
#  SPACE
# queer ADJ
# everything PRON
# is AUX
# to ADP
# - PUNCT
# day NOUN
# ! PUNCT
# And CCONJ
# yesterday NOUN
# things NOUN
# went VERB
# on ADP
# just ADV
# as ADV
# usual ADJ
# . PUNCT
#
#  SPACE
# I PRON
# wonder VERB
# if SCONJ
# Iâve NUM
# been AUX
# changed VERB
# in ADP
# the DET
# night NOUN
# ? PUNCT
# Let VERB
# me PRON
# think VERB
# : PUNCT
# was AUX
# I PRON
# the DET
#
#  SPACE
# same ADJ
# when SCONJ
# I PRON
# got VERB
# up ADP
# this DET
# morning NOUN
# ? PUNCT
# I PRON
# almost ADV
# think VERB
# I PRON
# can AUX
# remember VERB
# feeling VERB
#
#  SPACE
# a DET
# little ADJ
# different ADJ
# . PUNCT
# But CCONJ
# if SCONJ
# Iâm NOUN
# not PART
# the DET
# same ADJ
# , PUNCT
# the DET
# next ADJ
# question NOUN
# is AUX
# , PUNCT
# Who PRON
#
#  SPACE
# in ADP
# the DET
# world NOUN
# am AUX
# I PRON
# ? PUNCT
# Ah INTJ
# , PUNCT
# _ PROPN
# thatâs PUNCT
# _ PUNCT
# the DET
# great ADJ
# puzzle!â NOUN
# And CCONJ
# she PRON
# began VERB
#
#  SPACE
# thinking VERB
# over ADP
# all DET
# the DET
# children NOUN
# she PRON
# knew VERB
# that PRON
# were AUX
# of ADP
# the DET
# same ADJ
# age NOUN
# as ADP
#
#  SPACE
# herself PRON
# , PUNCT
# to PART
# see VERB
# if SCONJ
# she PRON
# could AUX
# have AUX
# been AUX
# changed VERB
# for ADP
# any PRON
# of ADP
# them PRON
# . PUNCT
#
#
#  SPACE
# âIâm VERB
# sure ADJ
# Iâm ADP
# not PART
# Ada PROPN
# , PUNCT
# â PROPN
# she PRON
# said VERB
# , PUNCT
# âfor SCONJ
# her PRON
# hair NOUN
# goes VERB
# in ADP
# such ADJ
# long ADJ
#
#  SPACE
# ringlets NOUN
# , PUNCT
# and CCONJ
# mine PRON
# doesnât NUM
# go VERB
# in ADP
# ringlets NOUN
# at ADV
# all ADV
# ; PUNCT
# and CCONJ
# Iâm NOUN
# sure ADJ
# I PRON
# canât AUX
#
#  SPACE
# be AUX
# Mabel PROPN
# , PUNCT
# for SCONJ
# I PRON
# know VERB
# all DET
# sorts NOUN
# of ADP
# things NOUN
# , PUNCT
# and CCONJ
# she PRON
# , PUNCT
# oh INTJ
# ! PUNCT
# she PRON
# knows VERB
# such DET
# a DET
#
#  SPACE
# very ADV
# little ADJ
# ! PUNCT
# Besides ADV
# , PUNCT
# _ PUNCT
# sheâs PUNCT
# _ PUNCT
# she PRON
# , PUNCT
# and CCONJ
# _ PUNCT
# Iâm NOUN
# _ PROPN
# I PRON
# , PUNCT
# andâoh PROPN
# dear PROPN
# , PUNCT
# how SCONJ
#
#  SPACE
# puzzling VERB
# it PRON
# all PRON
# is AUX
# ! PUNCT
# Iâll PUNCT
# try VERB
# if SCONJ
# I PRON
# know VERB
# all DET
# the DET
# things NOUN
# I PRON
# used VERB
# to PART
# know VERB
# . PUNCT
#
#  SPACE
# Let VERB
# me PRON
# see VERB
# : PUNCT
# four NUM
# times NOUN
# five NUM
# is AUX
# twelve NUM
# , PUNCT
# and CCONJ
# four NUM
# times NOUN
# six NUM
# is AUX
# thirteen NUM
# , PUNCT
#
#  SPACE
# and CCONJ
# four NUM
# times NOUN
# seven NUM
# isâoh PROPN
# dear NOUN
# ! PUNCT
# I PRON
# shall AUX
# never ADV
# get VERB
# to ADP
# twenty NUM
# at ADP
# that DET
#
#  SPACE
# rate NOUN
# ! PUNCT
# However ADV
# , PUNCT
# the DET
# Multiplication PROPN
# Table PROPN
# doesnât NOUN
# signify NOUN
# : PUNCT
# letâs PROPN
# try VERB
#
#  SPACE
# Geography PROPN
# . PUNCT
# London PROPN
# is AUX
# the DET
# capital NOUN
# of ADP
# Paris PROPN
# , PUNCT
# and CCONJ
# Paris PROPN
# is AUX
# the DET
# capital NOUN
# of ADP
#
#  SPACE
# Rome PROPN
# , PUNCT
# and CCONJ
# Romeâno PROPN
# , PUNCT
# _ PROPN
# thatâs PUNCT
# _ PUNCT
# all ADV
# wrong ADJ
# , PUNCT
# Iâm ADV
# certain ADJ
# ! PUNCT
# I PRON
# must AUX
# have AUX
# been AUX
#
#  SPACE
# changed VERB
# for ADP
# Mabel PROPN
# ! PUNCT
# Iâll PUNCT
# try VERB
# and CCONJ
# say VERB
# â_How PUNCT
# doth PROPN
# the DET
# little_âââ NOUN
# and CCONJ
# she PRON
#
#  SPACE
# crossed VERB
# her PRON
# hands NOUN
# on ADP
# her PRON
# lap NOUN
# as SCONJ
# if SCONJ
# she PRON
# were AUX
# saying VERB
# lessons NOUN
# , PUNCT
# and CCONJ
# began VERB
#
#  SPACE
# to PART
# repeat VERB
# it PRON
# , PUNCT
# but CCONJ
# her PRON
# voice NOUN
# sounded VERB
# hoarse ADJ
# and CCONJ
# strange ADJ
# , PUNCT
# and CCONJ
# the DET
# words NOUN
#
#  SPACE
# did AUX
# not PART
# come VERB
# the DET
# same ADJ
# as SCONJ
# they PRON
# used VERB
# to PART
# do VERB
# : PUNCT
# â PROPN
#
#
#  SPACE
# âHow PROPN
# doth NOUN
# the DET
# little ADJ
# crocodile NOUN
#
#      SPACE
# Improve VERB
# his PRON
# shining VERB
# tail NOUN
# , PUNCT
#
#  SPACE
# And CCONJ
# pour VERB
# the DET
# waters NOUN
# of ADP
# the DET
# Nile PROPN
#
#      SPACE
# On ADP
# every DET
# golden ADJ
# scale NOUN
# ! PUNCT
#
#
#  SPACE
# âHow PROPN
# cheerfully ADV
# he PRON
# seems VERB
# to PART
# grin VERB
# , PUNCT
#
#      SPACE
# How SCONJ
# neatly ADV
# spread VERB
# his PRON
# claws NOUN
# , PUNCT
#
#  SPACE
# And CCONJ
# welcome VERB
# little ADJ
# fishes NOUN
# in ADP
#
#      SPACE
# With ADP
# gently ADV
# smiling VERB
# jaws!â PROPN
#
#
#
#  SPACE
# âIâm PROPN
# sure ADJ
# those PRON
# are AUX
# not PART
# the DET
# right ADJ
# words NOUN
# , PUNCT
# â PROPN
# said VERB
# poor ADJ
# Alice PROPN
# , PUNCT
# and CCONJ
# her PRON
# eyes NOUN
#
#  SPACE
# filled VERB
# with ADP
# tears NOUN
# again ADV
# as SCONJ
# she PRON
# went VERB
# on ADP
# , PUNCT
# âI X
# must AUX
# be AUX
# Mabel PROPN
# after ADV
# all ADV
# , PUNCT
# and CCONJ
#
#  SPACE
# I PRON
# shall AUX
# have VERB
# to PART
# go VERB
# and CCONJ
# live VERB
# in ADP
# that DET
# poky ADJ
# little ADJ
# house NOUN
# , PUNCT
# and CCONJ
# have VERB
# next ADJ
# to ADP
#
#  SPACE
# no DET
# toys NOUN
# to PART
# play VERB
# with ADP
# , PUNCT
# and CCONJ
# oh INTJ
# ! PUNCT
# ever ADV
# so ADV
# many ADJ
# lessons NOUN
# to PART
# learn VERB
# ! PUNCT
# No INTJ
# , PUNCT
# Iâve NUM
#
#  SPACE
# made VERB
# up ADP
# my PRON
# mind NOUN
# about ADP
# it PRON
# ; PUNCT
# if SCONJ
# Iâm NOUN
# Mabel PROPN
# , PUNCT
# Iâll PUNCT
# stay VERB
# down ADV
# here ADV
# ! PUNCT
# Itâll NOUN
# be AUX
#
#  SPACE
# no DET
# use NOUN
# their PRON
# putting VERB
# their PRON
# heads NOUN
# down ADP
# and CCONJ
# saying VERB
# âCome VERB
# up ADP
# again ADV
# , PUNCT
# dear!â PROPN
#
#  SPACE
# I PRON
# shall AUX
# only ADV
# look VERB
# up ADP
# and CCONJ
# say VERB
# âWho NOUN
# am AUX
# I PRON
# then ADV
# ? PUNCT
# Tell VERB
# me PRON
# that SCONJ
# first ADV
# , PUNCT
# and CCONJ
#
#  SPACE
# then ADV
# , PUNCT
# if SCONJ
# I PRON
# like VERB
# being AUX
# that DET
# person NOUN
# , PUNCT
# Iâll PUNCT
# come VERB
# up ADP
# : PUNCT
# if SCONJ
# not PART
# , PUNCT
# Iâll PUNCT
# stay VERB
# down ADV
#
#  SPACE
# here ADV
# till SCONJ
# Iâm NOUN
# somebody PRON
# elseââbut ADP
# , PUNCT
# oh INTJ
# dear!â NOUN
# cried VERB
# Alice PROPN
# , PUNCT
# with ADP
# a DET
# sudden ADJ
#
#  SPACE
# burst NOUN
# of ADP
# tears NOUN
# , PUNCT
# âI X
# do AUX
# wish VERB
# they PRON
# _ PROPN
# would AUX
# _ PROPN
# put VERB
# their PRON
# heads NOUN
# down ADP
# ! PUNCT
# I PRON
# am AUX
# so ADV
#
#  SPACE
# _ PRON
# very ADV
# _ ADV
# tired ADJ
# of ADP
# being AUX
# all ADV
# alone ADJ
# here!â NOUN
#
#
#  SPACE
# As SCONJ
# she PRON
# said VERB
# this PRON
# she PRON
# looked VERB
# down ADP
# at ADP
# her PRON
# hands NOUN
# , PUNCT
# and CCONJ
# was AUX
# surprised ADJ
# to PART
# see VERB
#
#  SPACE
# that SCONJ
# she PRON
# had AUX
# put VERB
# on ADP
# one NUM
# of ADP
# the DET
# Rabbitâs PROPN
# little PROPN
# white ADJ
# kid NOUN
# gloves NOUN
# while SCONJ
#
#  SPACE
# she PRON
# was AUX
# talking VERB
# . PUNCT
# âHow PROPN
# _ PROPN
# can AUX
# _ NOUN
# I PRON
# have AUX
# done VERB
# that?â CCONJ
# she PRON
# thought VERB
# . PUNCT
# âI NOUN
# must AUX
# be AUX
#
#  SPACE
# growing VERB
# small ADJ
# again.â NOUN
# She PRON
# got VERB
# up ADP
# and CCONJ
# went VERB
# to ADP
# the DET
# table NOUN
# to PART
# measure VERB
#
#  SPACE
# herself PRON
# by ADP
# it PRON
# , PUNCT
# and CCONJ
# found VERB
# that SCONJ
# , PUNCT
# as ADV
# nearly ADV
# as SCONJ
# she PRON
# could AUX
# guess VERB
# , PUNCT
# she PRON
# was AUX
#
#  SPACE
# now ADV
# about ADV
# two NUM
# feet NOUN
# high ADJ
# , PUNCT
# and CCONJ
# was AUX
# going VERB
# on ADP
# shrinking VERB
# rapidly ADV
# : PUNCT
# she PRON
# soon ADV
#
#  SPACE
# found VERB
# out ADP
# that SCONJ
# the DET
# cause NOUN
# of ADP
# this PRON
# was AUX
# the DET
# fan NOUN
# she PRON
# was AUX
# holding VERB
# , PUNCT
# and CCONJ
# she PRON
#
#  SPACE
# dropped VERB
# it PRON
# hastily ADV
# , PUNCT
# just ADV
# in ADP
# time NOUN
# to PART
# avoid VERB
# shrinking VERB
# away ADV
# altogether ADV
# . PUNCT
#
#
#  SPACE
# âThat PRON
# _ PROPN
# was AUX
# _ PROPN
# a DET
# narrow ADJ
# escape!â NOUN
# said VERB
# Alice PROPN
# , PUNCT
# a DET
# good ADJ
# deal NOUN
# frightened VERB
# at ADP
# the DET
#
#  SPACE
# sudden ADJ
# change NOUN
# , PUNCT
# but CCONJ
# very ADV
# glad ADJ
# to PART
# find VERB
# herself PRON
# still ADV
# in ADP
# existence NOUN
# ; PUNCT
# âand NUM
#
#  SPACE
# now ADV
# for ADP
# the DET
# garden!â NOUN
# and CCONJ
# she PRON
# ran VERB
# with ADP
# all DET
# speed NOUN
# back ADV
# to ADP
# the DET
# little ADJ
#
#  SPACE
# door NOUN
# : PUNCT
# but CCONJ
# , PUNCT
# alas INTJ
# ! PUNCT
# the DET
# little ADJ
# door NOUN
# was AUX
# shut VERB
# again ADV
# , PUNCT
# and CCONJ
# the DET
# little ADJ
# golden ADJ
#
#  SPACE
# key NOUN
# was AUX
# lying VERB
# on ADP
# the DET
# glass NOUN
# table NOUN
# as ADP
# before ADV
# , PUNCT
# âand NUM
# things NOUN
# are AUX
# worse ADJ
# than ADP
#
#  SPACE
# ever ADV
# , PUNCT
# â PROPN
# thought VERB
# the DET
# poor ADJ
# child NOUN
# , PUNCT
# âfor SCONJ
# I PRON
# never ADV
# was AUX
# so ADV
# small ADJ
# as ADP
# this PRON
#
#  SPACE
# before ADV
# , PUNCT
# never ADV
# ! PUNCT
# And CCONJ
# I PRON
# declare VERB
# itâs PRON
# too ADV
# bad ADJ
# , PUNCT
# that SCONJ
# it PRON
# is!â PROPN
#
#
#  SPACE
# As SCONJ
# she PRON
# said VERB
# these DET
# words NOUN
# her PRON
# foot NOUN
# slipped VERB
# , PUNCT
# and CCONJ
# in ADP
# another DET
# moment NOUN
# , PUNCT
#
#  SPACE
# splash NOUN
# ! PUNCT
# she PRON
# was AUX
# up ADP
# to ADP
# her PRON
# chin NOUN
# in ADP
# salt NOUN
# water NOUN
# . PUNCT
# Her PRON
# first ADJ
# idea NOUN
# was AUX
# that SCONJ
#
#  SPACE
# she PRON
# had AUX
# somehow ADV
# fallen VERB
# into ADP
# the DET
# sea NOUN
# , PUNCT
# âand PROPN
# in ADP
# that DET
# case NOUN
# I PRON
# can AUX
# go VERB
# back ADV
# by ADP
#
#  SPACE
# railway NOUN
# , PUNCT
# â PROPN
# she PRON
# said VERB
# to ADP
# herself PRON
# . PUNCT
# ( PUNCT
# Alice PROPN
# had AUX
# been AUX
# to ADP
# the DET
# seaside NOUN
# once ADV
# in ADP
#
#  SPACE
# her PRON
# life NOUN
# , PUNCT
# and CCONJ
# had AUX
# come VERB
# to ADP
# the DET
# general ADJ
# conclusion NOUN
# , PUNCT
# that SCONJ
# wherever SCONJ
# you PRON
# go VERB
#
#  SPACE
# to ADP
# on ADP
# the DET
# English ADJ
# coast NOUN
# you PRON
# find VERB
# a DET
# number NOUN
# of ADP
# bathing NOUN
# machines NOUN
# in ADP
# the DET
#
#  SPACE
# sea NOUN
# , PUNCT
# some DET
# children NOUN
# digging VERB
# in ADP
# the DET
# sand NOUN
# with ADP
# wooden ADJ
# spades NOUN
# , PUNCT
# then ADV
# a DET
# row NOUN
#
#  SPACE
# of ADP
# lodging VERB
# houses NOUN
# , PUNCT
# and CCONJ
# behind ADP
# them PRON
# a DET
# railway NOUN
# station NOUN
# . PUNCT
# ) PUNCT
# However ADV
# , PUNCT
# she PRON
#
#  SPACE
# soon ADV
# made VERB
# out ADP
# that SCONJ
# she PRON
# was AUX
# in ADP
# the DET
# pool NOUN
# of ADP
# tears NOUN
# which PRON
# she PRON
# had AUX
# wept VERB
# when SCONJ
#
#  SPACE
# she PRON
# was AUX
# nine NUM
# feet NOUN
# high ADJ
# . PUNCT
#
#
#  SPACE
# âI NOUN
# wish VERB
# I PRON
# hadnât PRON
# cried VERB
# so SCONJ
# much!â NOUN
# said VERB
# Alice PROPN
# , PUNCT
# as SCONJ
# she PRON
# swam VERB
# about ADP
# , PUNCT
# trying VERB
#
#  SPACE
# to PART
# find VERB
# her PRON
# way NOUN
# out ADV
# . PUNCT
# âI PROPN
# shall AUX
# be AUX
# punished VERB
# for ADP
# it PRON
# now ADV
# , PUNCT
# I PRON
# suppose VERB
# , PUNCT
# by ADP
#
#  SPACE
# being AUX
# drowned VERB
# in ADP
# my PRON
# own ADJ
# tears NOUN
# ! PUNCT
# That DET
# _ NOUN
# will AUX
# _ PROPN
# be AUX
# a DET
# queer ADJ
# thing NOUN
# , PUNCT
# to PART
# be AUX
#
#  SPACE
# sure ADJ
# ! PUNCT
# However ADV
# , PUNCT
# everything PRON
# is AUX
# queer ADJ
# to ADP
# - PUNCT
# day.â NOUN
#
#
#  SPACE
# Just ADV
# then ADV
# she PRON
# heard VERB
# something PRON
# splashing VERB
# about ADP
# in ADP
# the DET
# pool NOUN
# a DET
# little ADJ
# way NOUN
#
#  SPACE
# off ADP
# , PUNCT
# and CCONJ
# she PRON
# swam VERB
# nearer NOUN
# to PART
# make VERB
# out ADP
# what PRON
# it PRON
# was AUX
# : PUNCT
# at ADP
# first ADV
# she PRON
# thought VERB
#
#  SPACE
# it PRON
# must AUX
# be AUX
# a DET
# walrus NOUN
# or CCONJ
# hippopotamus NOUN
# , PUNCT
# but CCONJ
# then ADV
# she PRON
# remembered VERB
# how SCONJ
# small ADJ
#
#  SPACE
# she PRON
# was AUX
# now ADV
# , PUNCT
# and CCONJ
# she PRON
# soon ADV
# made VERB
# out ADP
# that SCONJ
# it PRON
# was AUX
# only ADV
# a DET
# mouse NOUN
# that PRON
# had AUX
#
#  SPACE
# slipped VERB
# in ADP
# like ADP
# herself PRON
# . PUNCT
#
#
#  SPACE
# âWould AUX
# it PRON
# be AUX
# of ADP
# any DET
# use NOUN
# , PUNCT
# now ADV
# , PUNCT
# â PROPN
# thought VERB
# Alice PROPN
# , PUNCT
# âto PROPN
# speak VERB
# to ADP
# this DET
# mouse NOUN
# ? PUNCT
#
#  SPACE
# Everything PRON
# is AUX
# so ADV
# out ADV
# - PUNCT
# of ADP
# - PUNCT
# the DET
# - PUNCT
# way NOUN
# down ADV
# here ADV
# , PUNCT
# that SCONJ
# I PRON
# should AUX
# think VERB
# very ADV
#
#  SPACE
# likely ADJ
# it PRON
# can AUX
# talk VERB
# : PUNCT
# at ADP
# any DET
# rate NOUN
# , PUNCT
# thereâs PRON
# no DET
# harm NOUN
# in ADP
# trying.â PROPN
# So ADV
# she PRON
#
#  SPACE
# began VERB
# : PUNCT
# âO PROPN
# Mouse PROPN
# , PUNCT
# do AUX
# you PRON
# know VERB
# the DET
# way NOUN
# out ADP
# of ADP
# this DET
# pool NOUN
# ? PUNCT
# I PRON
# am AUX
# very ADV
# tired ADJ
#
#  SPACE
# of ADP
# swimming VERB
# about ADP
# here ADV
# , PUNCT
# O INTJ
# Mouse!â PROPN
# ( PUNCT
# Alice PROPN
# thought VERB
# this PRON
# must AUX
# be AUX
# the DET
# right ADJ
#
#  SPACE
# way NOUN
# of ADP
# speaking VERB
# to ADP
# a DET
# mouse NOUN
# : PUNCT
# she PRON
# had AUX
# never ADV
# done VERB
# such DET
# a DET
# thing NOUN
# before ADV
# , PUNCT
# but CCONJ
#
#  SPACE
# she PRON
# remembered VERB
# having AUX
# seen VERB
# in ADP
# her PRON
# brotherâs NOUN
# Latin PROPN
# Grammar PROPN
# , PUNCT
# âA PROPN
# mouseâof PROPN
#
#  SPACE
# a DET
# mouseâto NOUN
# a DET
# mouseâa PROPN
# mouseâO NOUN
# mouse!â NOUN
# ) PUNCT
# The DET
# Mouse PROPN
# looked VERB
# at ADP
# her PRON
# rather ADV
#
#  SPACE
# inquisitively ADV
# , PUNCT
# and CCONJ
# seemed VERB
# to ADP
# her PRON
# to PART
# wink VERB
# with ADP
# one NUM
# of ADP
# its PRON
# little ADJ
# eyes NOUN
# , PUNCT
#
#  SPACE
# but CCONJ
# it PRON
# said VERB
# nothing PRON
# . PUNCT
#
#
#  SPACE
# âPerhaps NOUN
# it PRON
# doesnât VERB
# understand VERB
# English PROPN
# , PUNCT
# â PROPN
# thought VERB
# Alice PROPN
# ; PUNCT
# âI PROPN
# daresay VERB
# itâs PROPN
#
#  SPACE
# a DET
# French ADJ
# mouse NOUN
# , PUNCT
# come VERB
# over ADP
# with ADP
# William PROPN
# the PRON
# Conqueror.â PUNCT
# ( PUNCT
# For ADP
# , PUNCT
# with ADP
# all DET
#
#  SPACE
# her PRON
# knowledge NOUN
# of ADP
# history NOUN
# , PUNCT
# Alice PROPN
# had VERB
# no DET
# very ADV
# clear ADJ
# notion NOUN
# how SCONJ
# long ADV
# ago ADP
#
#  SPACE
# anything PRON
# had AUX
# happened VERB
# . PUNCT
# ) PUNCT
# So ADV
# she PRON
# began VERB
# again ADV
# : PUNCT
# âOÃ¹ PROPN
# est ADJ
# ma PROPN
# chatte?â PUNCT
# which PRON
#
#  SPACE
# was AUX
# the DET
# first ADJ
# sentence NOUN
# in ADP
# her PRON
# French ADJ
# lesson NOUN
# - PUNCT
# book NOUN
# . PUNCT
# The DET
# Mouse PROPN
# gave VERB
# a DET
#
#  SPACE
# sudden ADJ
# leap NOUN
# out ADP
# of ADP
# the DET
# water NOUN
# , PUNCT
# and CCONJ
# seemed VERB
# to PART
# quiver ADV
# all ADV
# over ADV
# with ADP
#
#  SPACE
# fright ADJ
# . PUNCT
# âOh ADV
# , PUNCT
# I PRON
# beg VERB
# your PRON
# pardon!â NOUN
# cried VERB
# Alice PROPN
# hastily ADV
# , PUNCT
# afraid ADJ
# that SCONJ
# she PRON
#
#  SPACE
# had AUX
# hurt VERB
# the DET
# poor ADJ
# animalâs NUM
# feelings NOUN
# . PUNCT
# âI X
# quite ADV
# forgot VERB
# you PRON
# didnât NUM
# like ADP
#
#  SPACE
# cats.â NOUN
#
#
#  SPACE
# âNot NOUN
# like ADP
# cats!â NOUN
# cried VERB
# the DET
# Mouse PROPN
# , PUNCT
# in ADP
# a DET
# shrill ADJ
# , PUNCT
# passionate ADJ
# voice NOUN
# . PUNCT
# âWould AUX
#
#  SPACE
# _ PUNCT
# you PRON
# _ VERB
# like ADP
# cats NOUN
# if SCONJ
# you PRON
# were AUX
# me?â ADJ
#
#
#  SPACE
# âWell ADJ
# , PUNCT
# perhaps ADV
# not PART
# , PUNCT
# â PROPN
# said VERB
# Alice PROPN
# in ADP
# a DET
# soothing VERB
# tone NOUN
# : PUNCT
# âdonât NOUN
# be AUX
# angry ADJ
#
#  SPACE
# ...
# . PUNCT
#
#
#  SPACE
# The DET
# White PROPN
# Rabbit PROPN
# put VERB
# on ADP
# his PRON
# spectacles NOUN
# . PUNCT
# âWhere ADV
# shall AUX
# I PRON
# begin VERB
# , PUNCT
# please INTJ
#
#  SPACE
# your PRON
# Majesty?â NOUN
# he PRON
# asked VERB
# . PUNCT
#
#
#  SPACE
# âBegin PROPN
# at ADP
# the DET
# beginning NOUN
# , PUNCT
# â PROPN
# the DET
# King PROPN
# said VERB
# gravely ADV
# , PUNCT
# âand CCONJ
# go VERB
# on ADP
# till SCONJ
# you PRON
#
#  SPACE
# come VERB
# to ADP
# the DET
# end NOUN
# : PUNCT
# then ADV
# stop.â PROPN
#
#
#  SPACE
# These PRON
# were AUX
# the DET
# verses NOUN
# the DET
# White PROPN
# Rabbit PROPN
# read NOUN
# : PUNCT
# â PROPN
#
#
#  SPACE
# âThey PRON
# told VERB
# me PRON
# you PRON
# had AUX
# been AUX
# to ADP
# her PRON
# , PUNCT
#
#      SPACE
# And CCONJ
# mentioned VERB
# me PRON
# to ADP
# him PRON
# : PUNCT
#
#  SPACE
# She PRON
# gave VERB
# me PRON
# a DET
# good ADJ
# character NOUN
# , PUNCT
#
#      SPACE
# But CCONJ
# said VERB
# I PRON
# could AUX
# not PART
# swim VERB
# . PUNCT
#
#
#  SPACE
# He PRON
# sent VERB
# them PRON
# word NOUN
# I PRON
# had AUX
# not PART
# gone VERB
#
#      SPACE
# ( PUNCT
# We PRON
# know VERB
# it PRON
# to PART
# be AUX
# true ADJ
# ): PUNCT
#
#  SPACE
# If SCONJ
# she PRON
# should AUX
# push VERB
# the DET
# matter NOUN
# on ADP
# , PUNCT
#
#      SPACE
# What PRON
# would AUX
# become VERB
# of ADP
# you PRON
# ? PUNCT
#
#
#  SPACE
# I PRON
# gave VERB
# her PRON
# one NOUN
# , PUNCT
# they PRON
# gave VERB
# him PRON
# two NUM
# , PUNCT
#
#      SPACE
# You PRON
# gave VERB
# us PRON
# three NUM
# or CCONJ
# more ADJ
# ; PUNCT
#
#  SPACE
# They PRON
# all PRON
# returned VERB
# from ADP
# him PRON
# to ADP
# you PRON
# , PUNCT
#
#      SPACE
# Though SCONJ
# they PRON
# were AUX
# mine PRON
# before ADV
# . PUNCT
#
#
#  SPACE
# If SCONJ
# I PRON
# or CCONJ
# she PRON
# should AUX
# chance VERB
# to PART
# be AUX
#
#      SPACE
# Involved VERB
# in ADP
# this DET
# affair NOUN
# , PUNCT
#
#  SPACE
# He PRON
# trusts VERB
# to ADP
# you PRON
# to PART
# set VERB
# them PRON
# free ADJ
# , PUNCT
#
#      SPACE
# Exactly ADV
# as SCONJ
# we PRON
# were AUX
# . PUNCT
#
#
#  SPACE
# My PRON
# notion NOUN
# was AUX
# that SCONJ
# you PRON
# had AUX
# been AUX
#
#      SPACE
# ( PUNCT
# Before SCONJ
# she PRON
# had VERB
# this DET
# fit ADJ
# ) PUNCT
#
#  SPACE
# An DET
# obstacle NOUN
# that PRON
# came VERB
# between ADP
#
#      SPACE
# Him PRON
# , PUNCT
# and CCONJ
# ourselves PRON
# , PUNCT
# and CCONJ
# it PRON
# . PUNCT
#
#
#  SPACE
# Donât ADV
# let VERB
# him PRON
# know VERB
# she PRON
# liked VERB
# them PRON
# best ADV
# , PUNCT
#
#      SPACE
# For ADP
# this PRON
# must AUX
# ever ADV
# be AUX
#
#  SPACE
# A DET
# secret NOUN
# , PUNCT
# kept VERB
# from ADP
# all DET
# the DET
# rest NOUN
# , PUNCT
#
#      SPACE
# Between ADP
# yourself PRON
# and CCONJ
# me.â PROPN
#
#
#
#  SPACE
# âThatâs NOUN
# the DET
# most ADV
# important ADJ
# piece NOUN
# of ADP
# evidence NOUN
# weâve PROPN
# heard VERB
# yet ADV
# , PUNCT
# â PROPN
# said VERB
# the DET
#
#  SPACE
# King PROPN
# , PUNCT
# rubbing VERB
# his PRON
# hands NOUN
# ; PUNCT
# âso NOUN
# now ADV
# let VERB
# the DET
# juryââ PROPN
#
#
#  SPACE
# âIf PROPN
# any DET
# one NUM
# of ADP
# them PRON
# can AUX
# explain VERB
# it PRON
# , PUNCT
# â PROPN
# said VERB
# Alice PROPN
# , PUNCT
# ( PUNCT
# she PRON
# had AUX
# grown VERB
# so ADV
#
#  SPACE
# large ADJ
# in ADP
# the DET
# last ADJ
# few ADJ
# minutes NOUN
# that SCONJ
# she PRON
# wasnât VERB
# a DET
# bit NOUN
# afraid ADJ
# of ADP
#
#  SPACE
# interrupting VERB
# him PRON
# , PUNCT
# ) PUNCT
# âIâll X
# give VERB
# him PRON
# sixpence NOUN
# . PUNCT
# _ PUNCT
# I PRON
# _ NOUN
# donât NUM
# believe VERB
# thereâs SYM
#
#  SPACE
# an DET
# atom NOUN
# of ADP
# meaning NOUN
# in ADP
# it.â NOUN
#
#
#  SPACE
# The DET
# jury NOUN
# all PRON
# wrote VERB
# down ADP
# on ADP
# their PRON
# slates NOUN
# , PUNCT
# â_She NUM
# _ NUM
# doesnât NUM
# believe VERB
# thereâs SYM
#
#  SPACE
# an DET
# atom NOUN
# of ADP
# meaning NOUN
# in ADP
# it PRON
# , PUNCT
# â PROPN
# but CCONJ
# none NOUN
# of ADP
# them PRON
# attempted VERB
# to PART
# explain VERB
# the DET
#
#  SPACE
# paper NOUN
# . PUNCT
#
#
#  SPACE
# âIf PROPN
# thereâs PUNCT
# no DET
# meaning NOUN
# in ADP
# it PRON
# , PUNCT
# â PROPN
# said VERB
# the DET
# King PROPN
# , PUNCT
# âthat PRON
# saves VERB
# a DET
# world NOUN
# of ADP
#
#  SPACE
# trouble NOUN
# , PUNCT
# you PRON
# know VERB
# , PUNCT
# as SCONJ
# we PRON
# neednât VERB
# try VERB
# to PART
# find VERB
# any PRON
# . PUNCT
# And CCONJ
# yet ADV
# I PRON
# donât NUM
#
#  SPACE
# know VERB
# , PUNCT
# â PROPN
# he PRON
# went VERB
# on ADP
# , PUNCT
# spreading VERB
# out ADP
# the DET
# verses NOUN
# on ADP
# his PRON
# knee NOUN
# , PUNCT
# and CCONJ
# looking VERB
# at ADP
#
#  SPACE
# them PRON
# with ADP
# one NUM
# eye NOUN
# ; PUNCT
# âI PRON
# seem VERB
# to PART
# see VERB
# some DET
# meaning NOUN
# in ADP
# them PRON
# , PUNCT
# after ADV
# all ADV
# . PUNCT
#
#  SPACE
# ââ_said ADV
# I PRON
# could AUX
# not PART
# swim_ââ VERB
# you PRON
# canât NUM
# swim NOUN
# , PUNCT
# can AUX
# you?â NOUN
# he PRON
# added VERB
# , PUNCT
# turning VERB
#
#  SPACE
# to ADP
# the DET
# Knave PROPN
# . PUNCT
#
#
#  SPACE
# The DET
# Knave PROPN
# shook VERB
# his PRON
# head NOUN
# sadly ADV
# . PUNCT
# âDo PROPN
# I PRON
# look VERB
# like ADP
# it?â NOUN
# he PRON
# said VERB
# . PUNCT
# ( PUNCT
# Which PRON
# he PRON
#
#  SPACE
# certainly ADV
# did VERB
# _ PROPN
# not PART
# _ NOUN
# , PUNCT
# being AUX
# made VERB
# entirely ADV
# of ADP
# cardboard NOUN
# . PUNCT
# ) PUNCT
#
#
#  SPACE
# âAll ADV
# right NOUN
# , PUNCT
# so ADV
# far ADV
# , PUNCT
# â PROPN
# said VERB
# the DET
# King PROPN
# , PUNCT
# and CCONJ
# he PRON
# went VERB
# on ADP
# muttering VERB
# over ADP
# the DET
#
#  SPACE
# verses NOUN
# to ADP
# himself PRON
# : PUNCT
# ââ_We NOUN
# know VERB
# it PRON
# to PART
# be AUX
# true_ââ NUM
# thatâs NUM
# the DET
# jury NOUN
# , PUNCT
# of ADP
#
#  SPACE
# courseââ_I VERB
# gave VERB
# her PRON
# one NOUN
# , PUNCT
# they PRON
# gave VERB
# him PRON
# two_ââ NOUN
# why SCONJ
# , PUNCT
# that PRON
# must AUX
# be AUX
# what PRON
# he PRON
#
#  SPACE
# did VERB
# with ADP
# the DET
# tarts NOUN
# , PUNCT
# you PRON
# knowââ VERB
#
#
#  SPACE
# âBut PROPN
# , PUNCT
# it PRON
# goes VERB
# on ADP
# â_they PROPN
# all PRON
# returned VERB
# from ADP
# him PRON
# to AUX
# you_,ââ INTJ
# said VERB
# Alice PROPN
# . PUNCT
#
#
#  SPACE
# âWhy PROPN
# , PUNCT
# there ADV
# they PRON
# are!â PROPN
# said VERB
# the DET
# King PROPN
# triumphantly ADV
# , PUNCT
# pointing VERB
# to ADP
# the DET
#
#  SPACE
# tarts NOUN
# on ADP
# the DET
# table NOUN
# . PUNCT
# âNothing VERB
# can AUX
# be AUX
# clearer ADJ
# than ADP
# _ PRON
# that PRON
# _ PRON
# . PUNCT
# Then ADV
#
#  SPACE
# againââ_before PROPN
# she PRON
# had VERB
# this PRON
# fit_ââ NOUN
# you PRON
# never ADV
# had VERB
# fits NOUN
# , PUNCT
# my PRON
# dear NOUN
# , PUNCT
# I PRON
#
#  SPACE
# think?â NOUN
# he PRON
# said VERB
# to ADP
# the DET
# Queen PROPN
# . PUNCT
#
#
#  SPACE
# âNever!â NUM
# said VERB
# the DET
# Queen PROPN
# furiously ADV
# , PUNCT
# throwing VERB
# an DET
# inkstand NOUN
# at ADP
# the DET
# Lizard PROPN
#
#  SPACE
# as SCONJ
# she PRON
# spoke VERB
# . PUNCT
# ( PUNCT
# The DET
# unfortunate ADJ
# little ADJ
# Bill PROPN
# had AUX
# left VERB
# off ADP
# writing NOUN
# on ADP
# his PRON
#
#  SPACE
# slate NOUN
# with ADP
# one NUM
# finger NOUN
# , PUNCT
# as SCONJ
# he PRON
# found VERB
# it PRON
# made VERB
# no DET
# mark NOUN
# ; PUNCT
# but CCONJ
# he PRON
# now ADV
# hastily ADV
#
#  SPACE
# began VERB
# again ADV
# , PUNCT
# using VERB
# the DET
# ink NOUN
# , PUNCT
# that PRON
# was AUX
# trickling VERB
# down ADP
# his PRON
# face NOUN
# , PUNCT
# as ADV
# long ADV
#
#  SPACE
# as SCONJ
# it PRON
# lasted VERB
# . PUNCT
# ) PUNCT
#
#
#  SPACE
# âThen X
# the DET
# words NOUN
# donât NUM
# _ ADP
# fit ADJ
# _ PUNCT
# you PRON
# , PUNCT
# â PROPN
# said VERB
# the DET
# King PROPN
# , PUNCT
# looking VERB
# round ADV
# the DET
#
#  SPACE
# court NOUN
# with ADP
# a DET
# smile NOUN
# . PUNCT
# There PRON
# was VERB
# a DET
# dead ADJ
# silence NOUN
# . PUNCT
#
#
#  SPACE
# âItâs PROPN
# a DET
# pun!â NOUN
# the DET
# King PROPN
# added VERB
# in ADP
# an DET
# offended ADJ
# tone NOUN
# , PUNCT
# and CCONJ
# everybody PRON
#
#  SPACE
# laughed VERB
# , PUNCT
# âLet VERB
# the DET
# jury NOUN
# consider VERB
# their PRON
# verdict NOUN
# , PUNCT
# â PROPN
# the DET
# King PROPN
# said VERB
# , PUNCT
# for ADP
#
#  SPACE
# about ADP
# the DET
# twentieth ADJ
# time NOUN
# that DET
# day NOUN
# . PUNCT
#
#
#  SPACE
# âNo PROPN
# , PUNCT
# no!â PROPN
# said VERB
# the DET
# Queen PROPN
# . PUNCT
# âSentence PROPN
# firstâverdict PROPN
# afterwards.â PROPN
#
#
#  SPACE
# âStuff PROPN
# and CCONJ
# nonsense!â NOUN
# said VERB
# Alice PROPN
# loudly ADV
# . PUNCT
# âThe NOUN
# idea NOUN
# of ADP
# having VERB
# the DET
#
#  SPACE
# sentence NOUN
# first!â NOUN
#
#
#  SPACE
# âHold NOUN
# your PRON
# tongue!â NOUN
# said VERB
# the DET
# Queen PROPN
# , PUNCT
# turning VERB
# purple NOUN
# . PUNCT
#
#
#  SPACE
# âI NOUN
# wonât!â PROPN
# said VERB
# Alice PROPN
# . PUNCT
#
#
#  SPACE
# âOff PROPN
# with ADP
# her PRON
# head!â NOUN
# the DET
# Queen PROPN
# shouted VERB
# at ADP
# the DET
# top NOUN
# of ADP
# her PRON
# voice NOUN
# . PUNCT
# Nobody PRON
#
#  SPACE
# moved VERB
# . PUNCT
#
#
#  SPACE
# âWho VERB
# cares NOUN
# for ADP
# you?â NOUN
# said VERB
# Alice PROPN
# , PUNCT
# ( PUNCT
# she PRON
# had AUX
# grown VERB
# to ADP
# her PRON
# full ADJ
# size NOUN
# by ADP
#
#  SPACE
# this DET
# time NOUN
# . PUNCT
# ) PUNCT
# âYouâre VERB
# nothing PRON
# but SCONJ
# a DET
# pack NOUN
# of ADP
# cards!â PROPN
#
#
#  SPACE
# At ADP
# this PRON
# the DET
# whole ADJ
# pack NOUN
# rose VERB
# up ADP
# into ADP
# the DET
# air NOUN
# , PUNCT
# and CCONJ
# came AUX
# flying VERB
# down ADP
# upon SCONJ
#
#  SPACE
# her PRON
# : PUNCT
# she PRON
# gave VERB
# a DET
# little ADJ
# scream NOUN
# , PUNCT
# half NOUN
# of ADP
# fright ADJ
# and CCONJ
# half NOUN
# of ADP
# anger NOUN
# , PUNCT
# and CCONJ
#
#  SPACE
# tried VERB
# to PART
# beat VERB
# them PRON
# off ADP
# , PUNCT
# and CCONJ
# found VERB
# herself PRON
# lying VERB
# on ADP
# the DET
# bank NOUN
# , PUNCT
# with ADP
# her PRON
#
#  SPACE
# head NOUN
# in ADP
# the DET
# lap NOUN
# of ADP
# her PRON
# sister NOUN
# , PUNCT
# who PRON
# was AUX
# gently ADV
# brushing VERB
# away ADP
# some DET
# dead ADJ
#
#  SPACE
# leaves NOUN
# that PRON
# had AUX
# fluttered VERB
# down ADP
# from ADP
# the DET
# trees NOUN
# upon SCONJ
# her PRON
# face NOUN
# . PUNCT
#
#
#  SPACE
# âWake VERB
# up ADP
# , PUNCT
# Alice PROPN
# dear!â NOUN
# said VERB
# her PRON
# sister NOUN
# ; PUNCT
# âWhy NOUN
# , PUNCT
# what PRON
# a DET
# long ADJ
# sleep NOUN
# youâve PROPN
#
#  SPACE
# had!â PROPN
#
#
#  SPACE
# âOh PROPN
# , PUNCT
# Iâve PRON
# had VERB
# such DET
# a DET
# curious ADJ
# dream!â NOUN
# said VERB
# Alice PROPN
# , PUNCT
# and CCONJ
# she PRON
# told VERB
# her PRON
#
#  SPACE
# sister NOUN
# , PUNCT
# as ADV
# well ADV
# as SCONJ
# she PRON
# could AUX
# remember VERB
# them PRON
# , PUNCT
# all DET
# these DET
# strange ADJ
#
#  SPACE
# Adventures NOUN
# of ADP
# hers PRON
# that SCONJ
# you PRON
# have AUX
# just ADV
# been AUX
# reading VERB
# about ADP
# ; PUNCT
# and CCONJ
# when SCONJ
# she PRON
#
#  SPACE
# had AUX
# finished VERB
# , PUNCT
# her PRON
# sister NOUN
# kissed VERB
# her PRON
# , PUNCT
# and CCONJ
# said VERB
# , PUNCT
# âIt PROPN
# _ NOUN
# was AUX
# _ PRON
# a DET
# curious ADJ
#
#  SPACE
# dream NOUN
# , PUNCT
# dear ADJ
# , PUNCT
# certainly ADV
# : PUNCT
# but CCONJ
# now ADV
# run VERB
# in ADP
# to ADP
# your PRON
# tea NOUN
# ; PUNCT
# itâs PROPN
# getting VERB
# late.â NOUN
#
#  SPACE
# So ADV
# Alice PROPN
# got VERB
# up ADP
# and CCONJ
# ran VERB
# off ADP
# , PUNCT
# thinking VERB
# while SCONJ
# she PRON
# ran VERB
# , PUNCT
# as ADV
# well ADV
# she PRON
# might AUX
# , PUNCT
#
#  SPACE
# what PRON
# a DET
# wonderful ADJ
# dream NOUN
# it PRON
# had AUX
# been AUX
# . PUNCT
#
#
#
#  SPACE
# But CCONJ
# her PRON
# sister NOUN
# sat VERB
# still ADV
# just ADV
# as SCONJ
# she PRON
# left VERB
# her PRON
# , PUNCT
# leaning VERB
# her PRON
# head NOUN
# on ADP
# her PRON
#
#  SPACE
# hand NOUN
# , PUNCT
# watching VERB
# the DET
# setting VERB
# sun NOUN
# , PUNCT
# and CCONJ
# thinking NOUN
# of ADP
# little ADJ
# Alice PROPN
# and CCONJ
# all DET
#
#  SPACE
# her PRON
# wonderful ADJ
# Adventures NOUN
# , PUNCT
# till SCONJ
# she PRON
# too ADV
# began VERB
# dreaming VERB
# after ADP
# a DET
# fashion NOUN
# , PUNCT
#
#  SPACE
# and CCONJ
# this PRON
# was AUX
# her PRON
# dream NOUN
# : PUNCT
# â PROPN
#
#
#  SPACE
# First ADV
# , PUNCT
# she PRON
# dreamed VERB
# of ADP
# little ADJ
# Alice PROPN
# herself PRON
# , PUNCT
# and CCONJ
# once ADV
# again ADV
# the DET
# tiny ADJ
#
#  SPACE
# hands NOUN
# were AUX
# clasped VERB
# upon SCONJ
# her PRON
# knee NOUN
# , PUNCT
# and CCONJ
# the DET
# bright ADJ
# eager ADJ
# eyes NOUN
# were AUX
#
#  SPACE
# looking VERB
# up ADP
# into ADP
# hersâshe PROPN
# could AUX
# hear VERB
# the DET
# very ADJ
# tones NOUN
# of ADP
# her PRON
# voice NOUN
# , PUNCT
# and CCONJ
#
#  SPACE
# see VERB
# that SCONJ
# queer NOUN
# little ADJ
# toss NOUN
# of ADP
# her PRON
# head NOUN
# to PART
# keep VERB
# back ADV
# the DET
# wandering ADJ
# hair NOUN
#
#  SPACE
# that SCONJ
# _ PRON
# would AUX
# _ PROPN
# always ADV
# get VERB
# into ADP
# her PRON
# eyesâand PROPN
# still ADV
# as SCONJ
# she PRON
# listened VERB
# , PUNCT
# or CCONJ
#
#  SPACE
# seemed VERB
# to PART
# listen VERB
# , PUNCT
# the DET
# whole ADJ
# place NOUN
# around ADP
# her PRON
# became VERB
# alive ADJ
# with ADP
# the DET
#
#  SPACE
# strange ADJ
# creatures NOUN
# of ADP
# her PRON
# little ADJ
# sisterâs NOUN
# dream NOUN
# . PUNCT
#
#
#  SPACE
# The DET
# long ADJ
# grass NOUN
# rustled VERB
# at ADP
# her PRON
# feet NOUN
# as SCONJ
# the DET
# White PROPN
# Rabbit PROPN
# hurried VERB
# byâthe PROPN
#
#  SPACE
# frightened VERB
# Mouse PROPN
# splashed VERB
# his PRON
# way NOUN
# through ADP
# the DET
# neighbouring VERB
# poolâshe PROPN
#
#  SPACE
# could AUX
# hear VERB
# the DET
# rattle NOUN
# of ADP
# the DET
# teacups NOUN
# as SCONJ
# the DET
# March PROPN
# Hare PROPN
# and CCONJ
# his PRON
# friends NOUN
#
#  SPACE
# shared VERB
# their PRON
# never ADV
# - PUNCT
# ending VERB
# meal NOUN
# , PUNCT
# and CCONJ
# the DET
# shrill ADJ
# voice NOUN
# of ADP
# the DET
# Queen PROPN
#
#  SPACE
# ordering VERB
# off ADP
# her PRON
# unfortunate ADJ
# guests NOUN
# to ADP
# executionâonce NOUN
# more ADV
# the DET
# pig NOUN
# - PUNCT
# baby NOUN
#
#  SPACE
# was AUX
# sneezing VERB
# on ADP
# the DET
# Duchessâs NOUN
# knee NOUN
# , PUNCT
# while SCONJ
# plates NOUN
# and CCONJ
# dishes NOUN
# crashed VERB
#
#  SPACE
# around ADP
# itâonce NOUN
# more ADJ
# the DET
# shriek NOUN
# of ADP
# the DET
# Gryphon PROPN
# , PUNCT
# the DET
# squeaking NOUN
# of ADP
# the DET
#
#  SPACE
# Lizardâs PROPN
# slate NOUN
# - PUNCT
# pencil NOUN
# , PUNCT
# and CCONJ
# the DET
# choking NOUN
# of ADP
# the DET
# suppressed ADJ
# guinea NOUN
# - PUNCT
# pigs NOUN
# , PUNCT
#
#  SPACE
# filled VERB
# the DET
# air NOUN
# , PUNCT
# mixed VERB
# up ADP
# with ADP
# the DET
# distant ADJ
# sobs NOUN
# of ADP
# the DET
# miserable ADJ
# Mock PROPN
#
#  SPACE
# Turtle PROPN
# . PUNCT
#
#
#  SPACE
# So ADV
# she PRON
# sat VERB
# on ADP
# , PUNCT
# with ADP
# closed ADJ
# eyes NOUN
# , PUNCT
# and CCONJ
# half NOUN
# believed VERB
# herself PRON
# in ADP
#
#  SPACE
# Wonderland PROPN
# , PUNCT
# though SCONJ
# she PRON
# knew VERB
# she PRON
# had VERB
# but CCONJ
# to PART
# open VERB
# them PRON
# again ADV
# , PUNCT
# and CCONJ
# all PRON
#
#  SPACE
# would AUX
# change VERB
# to ADP
# dull ADJ
# realityâthe DET
# grass NOUN
# would AUX
# be AUX
# only ADV
# rustling VERB
# in ADP
# the DET
#
#  SPACE
# wind NOUN
# , PUNCT
# and CCONJ
# the DET
# pool NOUN
# rippling VERB
# to ADP
# the DET
# waving NOUN
# of ADP
# the DET
# reedsâthe DET
# rattling NOUN
#
#  SPACE
# teacups NOUN
# would AUX
# change VERB
# to ADP
# tinkling VERB
# sheep NOUN
# - PUNCT
# bells NOUN
# , PUNCT
# and CCONJ
# the DET
# Queenâs NOUN
# shrill NOUN
#
#  SPACE
# cries VERB
# to ADP
# the DET
# voice NOUN
# of ADP
# the DET
# shepherd NOUN
# boyâand PROPN
# the DET
# sneeze NOUN
# of ADP
# the DET
# baby NOUN
# , PUNCT
# the DET
#
#  SPACE
# shriek NOUN
# of ADP
# the DET
# Gryphon PROPN
# , PUNCT
# and CCONJ
# all DET
# the DET
# other ADJ
# queer NOUN
# noises NOUN
# , PUNCT
# would AUX
# change VERB
#
#  SPACE
# ( PUNCT
# she PRON
# knew VERB
# ) PUNCT
# to ADP
# the DET
# confused ADJ
# clamour NOUN
# of ADP
# the DET
# busy ADJ
# farm NOUN
# - PUNCT
# yardâwhile NOUN
# the DET
#
#  SPACE
# lowing NOUN
# of ADP
# the DET
# cattle NOUN
# in ADP
# the DET
# distance NOUN
# would AUX
# take VERB
# the DET
# place NOUN
# of ADP
# the DET
# Mock ADJ
#
#  SPACE
# Turtleâs NOUN
# heavy ADJ
# sobs NOUN
# . PUNCT
#
#
#  SPACE
# Lastly ADV
# , PUNCT
# she PRON
# pictured VERB
# to ADP
# herself PRON
# how SCONJ
# this DET
# same ADJ
# little ADJ
# sister NOUN
# of ADP
# hers PROPN
#
#  SPACE
# would AUX
# , PUNCT
# in ADP
# the DET
# after NOUN
# - PUNCT
# time NOUN
# , PUNCT
# be AUX
# herself PRON
# a DET
# grown ADJ
# woman NOUN
# ; PUNCT
# and CCONJ
# how SCONJ
# she PRON
# would AUX
#
#  SPACE
# keep VERB
# , PUNCT
# through ADP
# all DET
# her PRON
# riper NOUN
# years NOUN
# , PUNCT
# the DET
# simple ADJ
# and CCONJ
# loving VERB
# heart NOUN
# of ADP
# her PRON
#
#  SPACE
# childhood NOUN
# : PUNCT
# and CCONJ
# how SCONJ
# she PRON
# would AUX
# gather VERB
# about ADP
# her PRON
# other ADJ
# little ADJ
# children NOUN
# , PUNCT
#
#  SPACE
# and CCONJ
# make VERB
# _ PUNCT
# their PRON
# _ ADJ
# eyes NOUN
# bright ADJ
# and CCONJ
# eager ADJ
# with ADP
# many DET
# a DET
# strange ADJ
# tale NOUN
# , PUNCT
#
#  SPACE
# perhaps ADV
# even ADV
# with ADP
# the DET
# dream NOUN
# of ADP
# Wonderland PROPN
# of ADP
# long ADV
# ago ADV
# : PUNCT
# and CCONJ
# how SCONJ
# she PRON
#
#  SPACE
# would AUX
# feel VERB
# with ADP
# all DET
# their PRON
# simple ADJ
# sorrows NOUN
# , PUNCT
# and CCONJ
# find VERB
# a DET
# pleasure NOUN
# in ADP
# all PRON
#
#  SPACE
# their PRON
# simple ADJ
# joys NOUN
# , PUNCT
# remembering VERB
# her PRON
# own ADJ
# child NOUN
# - PUNCT
# life NOUN
# , PUNCT
# and CCONJ
# the DET
# happy ADJ
# summer NOUN
#
#  SPACE
# days NOUN
# . PUNCT
#
#
#  SPACE
# THE DET
# END PROPN
#
#  SPACE
# * PUNCT
# * PUNCT
# * PUNCT
# END NOUN
# OF ADP
# THE DET
# PROJECT PROPN
# GUTENBERG PROPN
# EBOOK VERB
# ALICE PROPN
# 'S PART
# ADVENTURES NOUN
# IN ADP
#
#  SPACE
# WONDERLAND PROPN
# * PUNCT
# * PUNCT
# * PUNCT
# --------------------------------------------------

# %% [markdown]
# ## Exercise 2
#
# Apply spaCy to extract the most meaningful content from your documents, considering options like excluding stop words or focusing on nouns (i.e. preprocessing and filtering).
#
# Perform a sentiment analysis on the refined data. Create visualization of your result.
#
# Summarize your results by explaining how sentiment changes across sections.

# %%
import spacy
import requests

# Load English language model
nlp = spacy.load("en_core_web_sm")

# Function to preprocess the text
def preprocess_text(text):
    # Remove any unnecessary characters or symbols (e.g., punctuation)
    # You can customize this based on your specific requirements
    return text.strip()

# Function to extract meaningful content using spaCy
def extract_meaningful_content(text):
    # Process the text with spaCy
    doc = nlp(text)
    
    # Extract meaningful information (e.g., named entities or parts of speech)
    meaningful_content = []
    for token in doc:
        # Example: Include only nouns and proper nouns
        if token.pos_ in ['NOUN', 'PROPN']:
            meaningful_content.append(token.text)
    
    return meaningful_content

# Fetching the text from the URL
url = "https://www.gutenberg.org/files/11/11-0.txt"
response = requests.get(url)
text = response.text

# Preprocess the text
preprocessed_text = preprocess_text(text)

# Extract meaningful content from the preprocessed text
meaningful_content = extract_meaningful_content(preprocessed_text)

# Print the extracted meaningful content
print(meaningful_content)
# Out:
# ['ï»¿ï', '»', '¿', 'START', 'PROJECT', 'GUTENBERG', 'ALICE', 'ADVENTURES', 'WONDERLAND', 'Illustration', 'Aliceâ\x80\x99s', 'Adventures', 'Wonderland', 'Lewis', 'Carroll', 'MILLENNIUM', 'FULCRUM', 'EDITION', 'Contents', 'CHAPTER', 'I.', 'Rabbit', 'Hole', 'CHAPTER', 'II', 'Pool', 'Tears', 'CHAPTER', 'III', 'Caucus', 'Race', 'Long', 'Tale', 'CHAPTER', 'IV', 'Rabbit', 'Sends', 'Little', 'Bill', 'CHAPTER', 'V.', 'Advice', 'Caterpillar', 'CHAPTER', 'VI', 'Pig', 'Pepper', 'CHAPTER', 'VII', 'Tea', 'Party', 'CHAPTER', 'VIII', 'Queenâ\x80\x99s', 'Croquet', 'Ground', 'CHAPTER', 'IX', 'Mock', 'Turtleâ\x80\x99s', 'Story', 'CHAPTER', 'X.', 'Lobster', 'Quadrille', 'CHAPTER', 'XI', 'Tarts', 'CHAPTER', 'XII', 'Evidence', 'CHAPTER', 'I.', 'Rabbit', 'Hole', 'Alice', 'sister', 'bank', 'book', 'sister', 'pictures', 'conversations', 'use', 'book', 'â\x80\x9d', 'Alice', 'â\x80\x9cwithout', 'pictures', 'conversations?â\x80\x9d', 'mind', 'day', 'pleasure', 'daisy', 'chain', 'trouble', 'daisies', 'White', 'Rabbit', 'eyes', 'Alice', 'way', 'Rabbit', 'â\x80\x9cOh', 'dear', 'time', 'Rabbit', 'watch', 'waistcoat', 'pocket', '_', 'Alice', 'feet', 'mind', 'rabbit', 'waistcoat', 'pocket', 'watch', 'curiosity', 'field', 'time', 'rabbit', 'hole', 'hedge', 'moment', 'Alice', 'world', 'rabbit', 'hole', 'tunnel', 'way', 'Alice', 'moment', 'well', 'plenty', 'time', 'sides', 'well', 'cupboards', 'book', 'shelves', 'maps', 'pictures', 'pegs', 'jar', 'shelves', 'â\x80\x9cORANGE', 'MARMALADEâ\x80\x9d', 'disappointment', 'jar', 'fear', 'cupboards', 'Alice', 'fall', 'stairs', 'theyâ\x80\x99ll', 'home', 'top', 'house!â\x80\x9d', 'fall', '_', 'end', 'miles', 'time?â\x80\x9d', 'centre', 'earth', 'miles', 'Alice', 'things', 'sort', 'lessons', 'schoolroom', '_', 'opportunity', 'knowledge', 'one', 'practice', 'â\x80\x9câ\x80\x94yes', 'distanceâ\x80\x94but', 'Latitude', 'Longitude', 'to?â\x80\x9d', 'Alice', 'idea', 'Latitude', 'Longitude', 'words', 'wonder', '_', 'earth', 'itâ\x80\x99ll', 'people', 'heads', 'Antipathies', '_', '_', 'one', 'time', 'word', 'â\x80\x9câ\x80\x94but', 'name', 'country', 'Maâ\x80\x99am', 'New', 'Zealand', 'Australia?â\x80\x9d', '_', 'youâ\x80\x99re', 'air', 'â\x80\x9cAnd', 'girl', 'sheâ\x80\x99ll', 'itâ\x80\x99ll', 'somewhere.â\x80\x9d', 'Alice', 'â\x80\x9cDinahâ\x80\x99ll', 'night', 'Dinah', 'cat', 'theyâ\x80\x99ll', 'saucer', 'milk', 'tea', 'time', 'Dinah', 'dear', 'mice', 'air', 'Iâ\x80\x99m', 'bat', 'thatâ\x80\x99s', 'mouse', 'cats', 'bats', 'wonder?â\x80\x9d', 'Alice', 'sort', 'way', 'â\x80\x9cDo', 'cats', 'bats', 'cats', 'bats?â\x80\x9d', 'â\x80\x9cDo', 'bats', 'cats?â\x80\x9d', 'answer', 'question', 'way', 'hand', 'hand', 'Dinah', 'â\x80\x9cNow', 'Dinah', 'truth', 'bat?â\x80\x9d', 'thump', 'heap', 'sticks', 'leaves', 'fall', 'Alice', 'bit', 'feet', 'moment', 'passage', 'White', 'Rabbit', 'sight', 'moment', 'Alice', 'wind', 'time', 'corner', 'â\x80\x9cOh', 'ears', 'whiskers', 'itâ\x80\x99s', 'getting!â\x80\x9d', 'corner', 'Rabbit', 'hall', 'row', 'lamps', 'roof', 'doors', 'hall', 'Alice', 'way', 'side', 'door', 'middle', 'table', 'glass', 'key', 'Aliceâ\x80\x99s', 'thought', 'doors', 'hall', 'locks', 'key', 'rate', 'time', 'curtain', 'door', 'inches', 'key', 'lock', 'delight', 'Alice', 'door', 'passage', 'rat', '-', 'hole', 'passage', 'garden', 'dark', 'hall', 'beds', 'flowers', 'fountains', 'head', 'doorway', 'head', 'â\x80\x9d', 'Alice', 'â\x80\x9cit', 'use', 'shoulders', 'telescope', 'begin.â\x80\x9d', 'way', 'things', 'Alice', 'things', 'use', 'door', 'table', 'half', 'key', 'rate', 'book', 'rules', 'people', 'telescopes', 'time', 'bottle', 'â\x80\x9cwhich', 'â\x80\x9d', 'Alice', 'neck', 'bottle', 'paper', 'label', 'words', 'ME', 'â\x80\x9d', 'letters', 'â\x80\x9d', 'Alice', '_', 'hurry', 'â\x80\x9cNo', 'â\x80\x9d', 'itâ\x80\x99s', 'â\x80\x98_poison_â\x80\x99', 'notâ\x80\x9d', 'histories', 'children', 'beasts', 'things', '_', 'rules', 'friends', 'poker', 'finger', '_', 'knife', 'bottle', 'â\x80\x9cpoison', 'â\x80\x9d', 'bottle', '_', '_', ' ...

# %%
import spacy
import requests
from spacy.lang.en.stop_words import STOP_WORDS
import matplotlib.pyplot as plt

# Load English language model
nlp = spacy.load("en_core_web_sm")

# Function to preprocess and filter text
def preprocess_and_filter(text):
    # Process the text with spaCy
    doc = nlp(text)
    
    # Filter out stop words and non-essential parts of speech
    filtered_tokens = [token.text.lower() for token in doc if token.text.lower() not in STOP_WORDS 
                      and token.pos_ in ['NOUN', 'VERB', 'ADJ', 'ADV']]
    
    return filtered_tokens

# Fetching the text from the URL
url = "https://www.gutenberg.org/files/11/11-0.txt"
response = requests.get(url)
text = response.text

# Preprocess and filter the text
filtered_text = preprocess_and_filter(text)

# Assign sentiment scores to words (dummy scores for demonstration)
sentiment_scores = {}
for word in filtered_text:
    # Example: Assign positive sentiment score for "happy" and negative sentiment score for "sad"
    if word == "happy":
        sentiment_scores[word] = 1
    elif word == "sad":
        sentiment_scores[word] = -1
    else:
        sentiment_scores[word] = 0  # Neutral sentiment for other words

# Calculate overall sentiment score for the document
overall_sentiment_score = sum(sentiment_scores[word] for word in filtered_text)

# Visualize the sentiment score
plt.bar(["Sentiment Score"], [overall_sentiment_score], color=['blue' if overall_sentiment_score >= 0 else 'red'])
plt.title('Sentiment Analysis')
plt.ylabel('Sentiment Score')
plt.show()

# Print the overall sentiment score
print("Overall Sentiment Score:", overall_sentiment_score)
# Out:
# Overall Sentiment Score: -1
